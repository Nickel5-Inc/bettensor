# %%
import time
import logging
import json
from substrateinterface import SubstrateInterface

class BlockMonitor:
    def __init__(self, substrate, logger, verbose=False):
        self.substrate = substrate
        self.logger = logger
        self.verbose = verbose  # If True, print full raw extrinsic and event data.
        self.should_exit = False  # Flag to stop monitoring
        # Dictionary to store pending stake extrinsic calls.
        # Keys: unique call IDs; Values: dict with call details.
        self.pending_calls = {}
        self.call_counter = 0  # Unique counter for pending calls

    def _get_block_hash(self, block_num):
        """Retrieve the block hash for a given block number."""
        try:
            block_hash = self.substrate.get_block_hash(block_num)
            return block_hash
        except Exception as e:
            self.logger.error(f"Error getting block hash for block {block_num}: {e}")
            return None

    def _get_extrinsics(self, block_hash):
        """Retrieve all extrinsics for a given block hash."""
        try:
            block = self.substrate.get_block(block_hash=block_hash)
            return block.get('extrinsics', [])
        except Exception as e:
            self.logger.error(f"Error getting extrinsics for block {block_hash}: {e}")
            return []

    def _process_extrinsics(self, block_num, extrinsics):
        """Process extrinsics in a block to record pending stake-related calls."""
        for ext in extrinsics:
            try:
                # Use ext.value if available; otherwise assume ext is a dict.
                ext_dict = ext.value if hasattr(ext, 'value') else ext

                if self.verbose:
                    self.logger.info("Raw extrinsic data: %s", json.dumps(ext_dict, indent=2, default=str))
                
                # Extract the coldkey from the extrinsic's "address" field.
                coldkey = ext_dict.get('address')
                
                call_info = ext_dict.get('call', {})
                call_module = call_info.get('call_module')
                call_function = call_info.get('call_function')
                # Only process stake-related calls from SubtensorModule.
                if call_module == 'SubtensorModule' and call_function in [
                    'add_stake', 'remove_stake', 'add_stake_limit', 'remove_stake_limit'
                ]:
                    params = call_info.get('call_args', [])
                    hotkey = None
                    call_amount = None  # The call amount as submitted in the extrinsic.
                    netuid_param = None
                    for param in params:
                        pname = param.get('name')
                        if pname == 'hotkey':
                            hotkey = param.get('value')
                        elif pname in ['amount', 'amount_staked', 'amount_unstaked']:
                            try:
                                call_amount = float(param.get('value', 0)) / 1e9
                            except Exception as conv_e:
                                self.logger.error(f"Error converting call amount from {param.get('value')}: {conv_e}")
                        elif pname == 'netuid':
                            try:
                                netuid_param = int(param.get('value', -1))
                            except Exception as conv_e:
                                self.logger.error(f"Error converting netuid: {conv_e}")
                    if call_amount is None:
                        self.logger.info(f"Call args for {call_function}: {json.dumps(params, indent=2, default=str)}")
                    
                    call_id = self.call_counter
                    self.call_counter += 1
                    self.pending_calls[call_id] = {
                        'block_num': block_num,
                        'call_function': call_function,
                        'coldkey': coldkey,      # The extrinsic signer (coldkey)
                        'hotkey': hotkey,
                        'netuid': netuid_param,
                        'call_amount': call_amount,  # The amount as submitted in the extrinsic.
                        'final_amount': None,        # To be updated based on event.
                        'validated': False,
                        'raw': call_info            # Full raw call info for debugging.
                    }
                    self.logger.info(
                        f"Recorded pending call {call_id} in block {block_num}: {call_function} - "
                        f"Coldkey: {coldkey}, Hotkey: {hotkey}, Call Amount: {call_amount if call_amount is not None else 'None'}, "
                        f"Netuid: {netuid_param}"
                    )
            except Exception as e:
                self.logger.error(f"Error processing extrinsic in block {block_num}: {e}")

    def _process_events(self, block_num, events_decoded):
        """Process events in a block and attempt to match them with pending extrinsic calls."""
        for idx, event_record in enumerate(events_decoded.value):
            try:
                if self.verbose:
                    self.logger.info("Raw event record %s: %s", idx, json.dumps(event_record, indent=2, default=str))
                
                event = event_record.get('event', {})
                module_id = event.get('module_id')
                event_id = event.get('event_id')
                attributes = event.get('attributes')
                
                # We care about stake events from SubtensorModule.
                if module_id == 'SubtensorModule' and event_id in ['StakeAdded', 'StakeRemoved']:
                    event_hotkey = None
                    event_netuid = None
                    event_amount = None
                    # Assume attributes is a list/tuple with at least 5 items:
                    # [caller, hotkey, amount, new_total, netuid]
                    if isinstance(attributes, (list, tuple)) and len(attributes) >= 5:
                        event_hotkey = attributes[1]
                        try:
                            event_amount = float(attributes[2]) / 1e9
                        except Exception as conv_e:
                            self.logger.error(f"Error converting event amount: {conv_e}")
                        try:
                            event_netuid = int(attributes[4])
                        except Exception as conv_e:
                            self.logger.error(f"Error converting event netuid: {conv_e}")
                    else:
                        self.logger.info(f"Event {idx} attributes not in expected format: {attributes}")
                    
                    self.logger.info(
                        f"Event {idx} in block {block_num}: {event_id} - Hotkey: {event_hotkey}, "
                        f"Event Amount: {event_amount if event_amount is not None else 'None'}, Netuid: {event_netuid}"
                    )
                    
                    # Mapping: for add_stake & add_stake_limit, expect StakeAdded; for remove_stake & remove_stake_limit, expect StakeRemoved.
                    mapping = {
                        'add_stake': 'StakeAdded',
                        'add_stake_limit': 'StakeAdded',
                        'remove_stake': 'StakeRemoved',
                        'remove_stake_limit': 'StakeRemoved'
                    }
                    for call_id, call_data in list(self.pending_calls.items()):
                        expected_event_id = mapping.get(call_data['call_function'])
                        if expected_event_id != event_id:
                            continue
                        if call_data['hotkey'] != event_hotkey or call_data['netuid'] != event_netuid:
                            continue
                        # For stake orders, record final amount from the event; for unstake orders, use the call amount.
                        if call_data['call_function'] in ['add_stake', 'add_stake_limit']:
                            final_amount = event_amount
                        else:
                            final_amount = call_data['call_amount']
                        call_data['final_amount'] = final_amount
                        fee = None
                        if call_data['call_function'] in ['add_stake', 'add_stake_limit'] and call_data['call_amount'] is not None and event_amount is not None:
                            fee = call_data['call_amount'] - event_amount
                        self.logger.info(
                            f"Validated pending call {call_id} (from block {call_data['block_num']}) with event "
                            f"{event_id} in block {block_num}: Coldkey: {call_data['coldkey']}, Hotkey: {event_hotkey}, "
                            f"Final Amount: {final_amount:.9f}"
                            f"{', Fee: ' + str(fee) if fee is not None else ''}, Netuid: {event_netuid}"
                        )
                        del self.pending_calls[call_id]
            except Exception as e:
                self.logger.error(f"Error processing event {idx} in block {block_num}: {e}")

    def _purge_old_calls(self, current_block):
        """Purge pending extrinsic calls older than a threshold.
           Standard stake calls are purged after 20 blocks.
           Limit orders (add_stake_limit, remove_stake_limit) are retained for 216000 blocks (~1 month).
        """
        to_delete = []
        for call_id, call_data in self.pending_calls.items():
            if call_data['call_function'] in ['add_stake_limit', 'remove_stake_limit']:
                threshold = 216000
            else:
                threshold = 20
            if current_block - call_data['block_num'] >= threshold:
                self.logger.info(f"Discarding pending call {call_id} from block {call_data['block_num']} (older than {threshold} blocks)")
                to_delete.append(call_id)
        for call_id in to_delete:
            del self.pending_calls[call_id]

    def block_header_handler(self, block_header, update_nr, subscription_id):
        """Callback for new block headers. Processes extrinsics and events and purges old pending calls."""
        self.logger.info("Block header received: %s", json.dumps(block_header, indent=2, default=str))
        try:
            block_num_val = block_header.get("header", {}).get("number")
            block_num = int(block_num_val, 16) if isinstance(block_num_val, str) else block_num_val
            self.logger.info("Extracted block number: %s", block_num)
            block_hash = self.substrate.get_block_hash(block_num)
            if not block_hash:
                self.logger.error("Could not compute block hash for block number %s", block_num)
                return
            self.logger.info("Computed block hash for block %s: %s", block_num, block_hash)
        except Exception as e:
            self.logger.error("Error computing block hash from header: %s", e)
            return

        extrinsics = self._get_extrinsics(block_hash)
        self._process_extrinsics(block_num, extrinsics)

        try:
            events_decoded = self.substrate.query("System", "Events", block_hash=block_hash)
            self.logger.info("Processing events for block %s", block_num)
            self._process_events(block_num, events_decoded)
        except Exception as e:
            self.logger.error(f"Error querying events for block {block_hash}: {e}")

        self._purge_old_calls(block_num)

    def start_monitoring(self):
        self.logger.info(f"Starting block monitoring at {self.substrate.url}")
        subscription = self.substrate.subscribe_block_headers(self.block_header_handler)
        try:
            while not self.should_exit:
                time.sleep(1)
        except KeyboardInterrupt:
            self.logger.info("Keyboard interrupt detected, stopping monitoring.")
            self.should_exit = True
        subscription.unsubscribe()
        self.logger.info("Block monitoring stopped")

# Example usage:
if __name__ == "__main__":
    logging.basicConfig(level=logging.INFO)
    logger = logging.getLogger("BlockMonitor")
    
    substrate = SubstrateInterface(
        url="wss://entrypoint-finney.opentensor.ai:443"
    )
    # Set verbose=True to print full raw extrinsic and event data.
    monitor = BlockMonitor(substrate, logger, verbose=False)
    monitor.start_monitoring()
# Out:
# INFO:BlockMonitor:Starting block monitoring at wss://entrypoint-finney.opentensor.ai:443
# INFO:BlockMonitor:Block header received: {
#   "header": {
#     "parentHash": "0x2f801277b54f3d015b6ac0a5322487dcb3eebb260af5e998799b5a609e809687",
#     "number": 5057195,
#     "stateRoot": "0x9e9989d1147c4bad764b344ae6606004aea7df9423fdcfed4e4ab99d8b52d6e5",
#     "extrinsicsRoot": "0x092294a3c5cfe4dd740ee4757cfddd6690b4f1bd6d68c83da71cd4bf5a4f85e3",
#     "digest": {
#       "logs": [
#         "{'PreRuntime': ('0x61757261', '0x83f4a50800000000')}",
#         "{'Consensus': ('0x66726f6e', '0x010c03cdc726b443a3af6f56bef9fb5be70d668c70d9367ad0c9579857e1bdc1b900')}",
#         "{'Seal': ('0x61757261', '0x2ce3a4c09f612573db32adea6fcee2932dc568441c6a378afcd66ede20a3a564ea551cf370a72854b4247c7d5df215c98ddeb04ab1d82cbbaf05e1dc5c718a89')}"
#       ]
#     }
#   }
# }
# INFO:BlockMonitor:Extracted block number: 5057195
# INFO:BlockMonitor:Computed block hash for block 5057195: 0x511958f56fffb4cd0ed8fa91b252bdd980fbb49c5af633c1c889d8825c7e1129
# INFO:BlockMonitor:Recorded pending call 0 in block 5057195: add_stake - Coldkey: 5F9GPtA1ZZadPzFgF5MvunwxCcnCcHL8Zic1D2VDVfpSG67E, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2,
#     "stateRoot": "0x0008eb45814f3a67f04c2827e4d94308d095a177422ec2c5a13b690e5981c1c5",
#     "extrinsicsRoot": "0xbe5ade64532eba104ce497c186411e1cd183b1b6d07313a1821ded8cbf3e7344",
#     "digest": {
#       "logs": [
#         "{'PreRuntime': ('0x61757261', '0x84f4a50800000000')}",
#         "{'Consensus': ('0x66726f6e', '0x016c43576c20e5078fba920b8a2689cf8c60b134ff02762321b6a19dcb9e1a5c3100')}",
#         "{'Seal': ('0x61757261', '0xdec862aab3dc44beb58ece53227ef1aeccf507158b5a6ad46233bd552f7f4b66124611e40686414a2e35bc8cdfa7638765bbdbbeafe5bc232695a585fe744186')}"
#       ]
#     }
#   }
# }
# INFO:BlockMonitor:Extracted block number: 5057196
# INFO:BlockMonitor:Computed block hash for block 5057196: 0x26d572d4a2e14d3b11df3fb1e61c78dae4659c28638e3f7eac84454a2782049b
# INFO:BlockMonitor:Recorded pending call 8 in block 5057196: add_stake - Coldkey: 5F9GPtA1ZZadPzFgF5MvunwxCcnCcHL8Zic1D2VDVfpSG67E, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Call Amount: 0.0006, Netuid: 5
# INFO:BlockMonitor:Recorded pending call 9 in block 5057196: add_stake - Coldkey: 5D72yvXBh52CXbKC83SDXyNFGhe6xgNDLxdKbDQKaTYumWaW, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Call Amount: 0.1, Netuid: 64
# INFO:BlockMonitor:Recorded pending call 10 in block 5057196: remove_stake - Coldkey: 5DL8qvmRdbx9sRHDPu5BSoMu2QLEMa7ta1c7YeRVb6h1XsQQ, Hotkey: 5Coqv6sS6HjRMgVQeHcWTmNQMGbJLKFdJAuu83jf3FXAzddZ, Call Amount: 0.89254167, Netuid: 1
# INFO:BlockMonitor:Recorded pending call 11 in block 5057196: add_stake - Coldkey: 5G9zepDQkiQpZnMggYsYnqee2BgtdwCqheNaHtZ1kqa2rzXj, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Call Amount: 2.0, Netuid: 70
# INFO:BlockMonitor:Recorded pending call 12 in block 5057196: add_stake - Coldkey: 5HKisem4LaHytpZ79wGhAXFGSt3CWdbaa5SnMn3haYbQiVDN, Hotkey: 5F2CsUDVbRbVMXTh9fAzF9GacjVX7UapvRxidrxe7z8BYckQ, Call Amount: 0.00055, Netuid: 24
# INFO:BlockMonitor:Recorded pending call 13 in block 5057196: remove_stake - Coldkey: 5DFdzQ3LBsrX4m8zEs7tiyqcd75pnh8smgNoTph94nkrMn86, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Call Amount: 0.69924515, Netuid: 71
# INFO:BlockMonitor:Recorded pending call 14 in block 5057196: remove_stake - Coldkey: 5EjzmUXfuVBJpy7AcHGDTJGroAPCDeyvgsLdvYmhzSKt75jm, Hotkey: 5FjXBhJvVWXfubWy5ZDo4muywr4wqmKvoGSWPrf7pGDRZRcU, Call Amount: 0.188202865, Netuid: 0
# INFO:BlockMonitor:Recorded pending call 15 in block 5057196: remove_stake_limit - Coldkey: 5Esx9Dbpzmy4mz5UNkdN5ncTRNwZqLX9oJCpgZqNXpMZrksb, Hotkey: 5DqZKNc6n7FW92kjkJo7fcWPYfcYqv5sASA7HtwGaUnPtYUD, Call Amount: 3.218957745, Netuid: 63
# INFO:BlockMonitor:Processing events for block 5057196
# INFO:BlockMonitor:Event 43 in block 5057196: StakeAdded - Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Event Amount: 0.00055, Netuid: 5
# INFO:BlockMonitor:Validated pending call 8 (from block 5057196) with event StakeAdded in block 5057196: Coldkey: 5F9GPtA1ZZadPzFgF5MvunwxCcnCcHL8Zic1D2VDVfpSG67E, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Final Amount: 0.000550000, Fee: 4.9999999999999914e-05, Netuid: 5
# INFO:BlockMonitor:Event 51 in block 5057196: StakeAdded - Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Event Amount: 0.09995, Netuid: 64
# INFO:BlockMonitor:Validated pending call 9 (from block 5057196) with event StakeAdded in block 5057196: Coldkey: 5D72yvXBh52CXbKC83SDXyNFGhe6xgNDLxdKbDQKaTYumWaW, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Final Amount: 0.099950000, Fee: 5.000000000000837e-05, Netuid: 64
# INFO:BlockMonitor:Event 56 in block 5057196: StakeRemoved - Hotkey: 5Coqv6sS6HjRMgVQeHcWTmNQMGbJLKFdJAuu83jf3FXAzddZ, Event Amount: 0.029837505, Netuid: 1
# INFO:BlockMonitor:Validated pending call 10 (from block 5057196) with event StakeRemoved in block 5057196: Coldkey: 5DL8qvmRdbx9sRHDPu5BSoMu2QLEMa7ta1c7YeRVb6h1XsQQ, Hotkey: 5Coqv6sS6HjRMgVQeHcWTmNQMGbJLKFdJAuu83jf3FXAzddZ, Final Amount: 0.892541670, Netuid: 1
# INFO:BlockMonitor:Event 61 in block 5057196: StakeAdded - Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Event Amount: 1.99995, Netuid: 70
# INFO:BlockMonitor:Validated pending call 11 (from block 5057196) with event StakeAdded in block 5057196: Coldkey: 5G9zepDQkiQpZnMggYsYnqee2BgtdwCqheNaHtZ1kqa2rzXj, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Final Amount: 1.999950000, Fee: 5.0000000000105516e-05, Netuid: 70
# INFO:BlockMonitor:Event 65 in block 5057196: StakeAdded - Hotkey: 5F2CsUDVbRbVMXTh9fAzF9GacjVX7UapvRxidrxe7z8BYckQ, Event Amount: 0.0005, Netuid: 24
# INFO:BlockMonitor:Validated pending call 12 (from block 5057196) with event StakeAdded in block 5057196: Coldkey: 5HKisem4LaHytpZ79wGhAXFGSt3CWdbaa5SnMn3haYbQiVDN, Hotkey: 5F2CsUDVbRbVMXTh9fAzF9GacjVX7UapvRxidrxe7z8BYckQ, Final Amount: 0.000500000, Fee: 5.000000000000002e-05, Netuid: 24
# INFO:BlockMonitor:Event 70 in block 5057196: StakeRemoved - Hotkey: 5CoJCv3RpnawCKAYybWVLX8wH75VSPSMtJRX5gFgf61gEFnA, Event Amount: 0.13050125, Netuid: 6
# INFO:BlockMonitor:Event 74 in block 5057196: StakeRemoved - Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Event Amount: 0.009942143, Netuid: 71
# INFO:BlockMonitor:Validated pending call 13 (from block 5057196) with event StakeRemoved in block 5057196: Coldkey: 5DFdzQ3LBsrX4m8zEs7tiyqcd75pnh8smgNoTph94nkrMn86, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Final Amount: 0.699245150, Netuid: 71
# INFO:BlockMonitor:Event 84 in block 5057196: StakeRemoved - Hotkey: 5FjXBhJvVWXfubWy5ZDo4muywr4wqmKvoGSWPrf7pGDRZRcU, Event Amount: 0.188152865, Netuid: 0
# INFO:BlockMonitor:Validated pending call 14 (from block 5057196) with event StakeRemoved in block 5057196: Coldkey: 5EjzmUXfuVBJpy7AcHGDTJGroAPCDeyvgsLdvYmhzSKt75jm, Hotkey: 5FjXBhJvVWXfubWy5ZDo4muywr4wqmKvoGSWPrf7pGDRZRcU, Final Amount: 0.188202865, Netuid: 0
# INFO:BlockMonitor:Event 90 in block 5057196: StakeRemoved - Hotkey: 5DqZKNc6n7FW92kjkJo7fcWPYfcYqv5sASA7HtwGaUnPtYUD, Event Amount: 0.00488398, Netuid: 63
# INFO:BlockMonitor:Validated pending call 15 (from block 5057196) with event StakeRemoved in block 5057196: Coldkey: 5Esx9Dbpzmy4mz5UNkdN5ncTRNwZqLX9oJCpgZqNXpMZrksb, Hotkey: 5DqZKNc6n7FW92kjkJo7fcWPYfcYqv5sASA7HtwGaUnPtYUD, Final Amount: 3.218957745, Netuid: 63
# INFO:BlockMonitor:Block header received: {
#   "header": {
#     "parentHash": "0x26d572d4a2e14d3b11df3fb1e61c78dae4659c28638e3f7eac84454a2782049b",
#     "number": 5057197,
#     "stateRoot": "0x293a3ad3f0e4cdc5bb1c5dc4be2669ce690febb4864796e2fa0ec09ef9a7695d",
#     "extrinsicsRoot": "0xa349461cc62e146a9240f4d8d9f5bdc7e7717465f109ccea72c47f0994b968fa",
#     "digest": {
#       "logs": [
#         "{'PreRuntime': ('0x61757261', '0x85f4a50800000000')}",
#         "{'Consensus': ('0x66726f6e', '0x011f426fd74b6999363524555dda6e5d737a2de7aeedba11810bfea0368ab37fb800')}",
#         "{'Seal': ('0x61757261', '0x86f37162895f88221500507865373db45a0e796fdda490c865297d33f51dbf4cc8a145bb8af7befe9aec542586653268b8c79c6a984ca03a2b2c023094331084')}"
#       ]
#     }
#   }
# }
# INFO:BlockMonitor:Extracted block number: 5057197
# INFO:BlockMonitor:Computed block hash for block 5057197: 0xc31d96d7021990992634aa58eed5bc299049a6477f174cbffc851f0177c76a9e
# INFO:BlockMonitor:Recorded pending call 16 in block 5057197: add_stake - Coldkey: 5FsEzFtqotM8yEHup7ixVidWP6s9Qs9vacj5mXqRLvqZCk4x, Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Call Amount: 4.0, Netuid: 70
# INFO:BlockMonitor:Recorded pending call 17 in block 5057197: add_stake - Coldkey: 5F9GPtA1ZZadPzFgF5MvunwxCcnCcHL8Zic1D2VDVfpSG67E, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Call Amount: 0.0006, Netuid: 5
# INFO:BlockMonitor:Recorded pending call 18 in block 5057197: add_stake - Coldkey: 5D72yvXBh52CXbKC83SDXyNFGhe6xgNDLxdKbDQKaTYumWaW, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Call Amount: 0.1, Netuid: 19
# INFO:BlockMonitor:Recorded pending call 19 in block 5057197: remove_stake - Coldkey: 5DL8qvmRdbx9sRHDPu5BSoMu2QLEMa7ta1c7YeRVb6h1XsQQ, Hotkey: 5FeS9y3ciDMjdkPADbVuezLvqfN2gyYWATK8QyuS9PziGWtR, Call Amount: 0.924166361, Netuid: 1
# INFO:BlockMonitor:Recorded pending call 20 in block 5057197: add_stake - Coldkey: 5HKisem4LaHytpZ79wGhAXFGSt3CWdbaa5SnMn3haYbQiVDN, Hotkey: 5F2CsUDVbRbVMXTh9fAzF9GacjVX7UapvRxidrxe7z8BYckQ, Call Amount: 0.00055, Netuid: 24
# INFO:BlockMonitor:Recorded pending call 21 in block 5057197: remove_stake - Coldkey: 5DFdzQ3LBsrX4m8zEs7tiyqcd75pnh8smgNoTph94nkrMn86, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Call Amount: 0.699982129, Netuid: 71
# INFO:BlockMonitor:Recorded pending call 22 in block 5057197: remove_stake - Coldkey: 5EjzmUXfuVBJpy7AcHGDTJGroAPCDeyvgsLdvYmhzSKt75jm, Hotkey: 5D9h5bev96CVrKYTctegkUvtXSDX4Lev7WguDbUkc7QdDDxX, Call Amount: 0.120339167, Netuid: 0
# INFO:BlockMonitor:Recorded pending call 23 in block 5057197: add_stake - Coldkey: 5G9zepDQkiQpZnMggYsYnqee2BgtdwCqheNaHtZ1kqa2rzXj, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Call Amount: 2.0, Netuid: 70
# INFO:BlockMonitor:Processing events for block 5057197
# INFO:BlockMonitor:Event 23 in block 5057197: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 3.99995, Netuid: 70
# INFO:BlockMonitor:Validated pending call 16 (from block 5057197) with event StakeAdded in block 5057197: Coldkey: 5FsEzFtqotM8yEHup7ixVidWP6s9Qs9vacj5mXqRLvqZCk4x, Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Final Amount: 3.999950000, Fee: 4.999999999988347e-05, Netuid: 70
# INFO:BlockMonitor:Event 44 in block 5057197: StakeAdded - Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Event Amount: 0.00055, Netuid: 5
# INFO:BlockMonitor:Validated pending call 17 (from block 5057197) with event StakeAdded in block 5057197: Coldkey: 5F9GPtA1ZZadPzFgF5MvunwxCcnCcHL8Zic1D2VDVfpSG67E, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Final Amount: 0.000550000, Fee: 4.9999999999999914e-05, Netuid: 5
# INFO:BlockMonitor:Event 48 in block 5057197: StakeAdded - Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Event Amount: 0.09995, Netuid: 19
# INFO:BlockMonitor:Validated pending call 18 (from block 5057197) with event StakeAdded in block 5057197: Coldkey: 5D72yvXBh52CXbKC83SDXyNFGhe6xgNDLxdKbDQKaTYumWaW, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Final Amount: 0.099950000, Fee: 5.000000000000837e-05, Netuid: 19
# INFO:BlockMonitor:Event 53 in block 5057197: StakeRemoved - Hotkey: 5FeS9y3ciDMjdkPADbVuezLvqfN2gyYWATK8QyuS9PziGWtR, Event Amount: 0.030895668, Netuid: 1
# INFO:BlockMonitor:Validated pending call 19 (from block 5057197) with event StakeRemoved in block 5057197: Coldkey: 5DL8qvmRdbx9sRHDPu5BSoMu2QLEMa7ta1c7YeRVb6h1XsQQ, Hotkey: 5FeS9y3ciDMjdkPADbVuezLvqfN2gyYWATK8QyuS9PziGWtR, Final Amount: 0.924166361, Netuid: 1
# INFO:BlockMonitor:Event 58 in block 5057197: StakeAdded - Hotkey: 5F2CsUDVbRbVMXTh9fAzF9GacjVX7UapvRxidrxe7z8BYckQ, Event Amount: 0.0005, Netuid: 24
# INFO:BlockMonitor:Validated pending call 20 (from block 5057197) with event StakeAdded in block 5057197: Coldkey: 5HKisem4LaHytpZ79wGhAXFGSt3CWdbaa5SnMn3haYbQiVDN, Hotkey: 5F2CsUDVbRbVMXTh9fAzF9GacjVX7UapvRxidrxe7z8BYckQ, Final Amount: 0.000500000, Fee: 5.000000000000002e-05, Netuid: 24
# INFO:BlockMonitor:Event 63 in block 5057197: StakeRemoved - Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Event Amount: 0.009942143, Netuid: 71
# INFO:BlockMonitor:Validated pending call 21 (from block 5057197) with event StakeRemoved in block 5057197: Coldkey: 5DFdzQ3LBsrX4m8zEs7tiyqcd75pnh8smgNoTph94nkrMn86, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Final Amount: 0.699982129, Netuid: 71
# INFO:BlockMonitor:Event 75 in block 5057197: StakeRemoved - Hotkey: 5D9h5bev96CVrKYTctegkUvtXSDX4Lev7WguDbUkc7QdDDxX, Event Amount: 0.120289167, Netuid: 0
# INFO:BlockMonitor:Validated pending call 22 (from block 5057197) with event StakeRemoved in block 5057197: Coldkey: 5EjzmUXfuVBJpy7AcHGDTJGroAPCDeyvgsLdvYmhzSKt75jm, Hotkey: 5D9h5bev96CVrKYTctegkUvtXSDX4Lev7WguDbUkc7QdDDxX, Final Amount: 0.120339167, Netuid: 0
# INFO:BlockMonitor:Event 80 in block 5057197: StakeAdded - Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Event Amount: 1.99995, Netuid: 70
# INFO:BlockMonitor:Validated pending call 23 (from block 5057197) with event StakeAdded in block 5057197: Coldkey: 5G9zepDQkiQpZnMggYsYnqee2BgtdwCqheNaHtZ1kqa2rzXj, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Final Amount: 1.999950000, Fee: 5.0000000000105516e-05, Netuid: 70
# INFO:BlockMonitor:Block header received: {
#   "header": {
#     "parentHash": "0xc31d96d7021990992634aa58eed5bc299049a6477f174cbffc851f0177c76a9e",
#     "number": 5057198,
#     "stateRoot": "0x695d988e2cf7c999bdbc94c107adee6d99d3e4c063af955a4cfa2b532a6faa95",
#     "extrinsicsRoot": "0xffbd5bb502acef676e525963937d772a3445d4deebf87c5b1ce8033f52d06cd1",
#     "digest": {
#       "logs": [
#         "{'PreRuntime': ('0x61757261', '0x86f4a50800000000')}",
#         "{'Consensus': ('0x66726f6e', '0x01e8a90747413d09d7c7de61b963521bfc9bbc6b5e93f1d4dae250f584ca38f5e100')}",
#         "{'Seal': ('0x61757261', '0x0252a6ec1f1ba40be0a83b67503e3dfb30f5177f8b9239ddfec95bafe682cd01635fe991471b5306f97c3cbb4536de73c047764317996d78eabd51898002ea8f')}"
#       ]
#     }
#   }
# }
# INFO:BlockMonitor:Extracted block number: 5057198
# INFO:BlockMonitor:Computed block hash for block 5057198: 0xad3a2bd69e1beabf9f53f3ccc3f60f1b7695e5dadd5ae9363c6ce99f43d0bcb2
# INFO:BlockMonitor:Recorded pending call 24 in block 5057198: add_stake - Coldkey: 5F9GPtA1ZZadPzFgF5MvunwxCcnCcHL8Zic1D2VDVfpSG67E, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Call Amount: 0.0006, Netuid: 5
# INFO:BlockMonitor:Recorded pending call 25 in block 5057198: add_stake - Coldkey: 5D72yvXBh52CXbKC83SDXyNFGhe6xgNDLxdKbDQKaTYumWaW, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Call Amount: 0.1, Netuid: 51
# INFO:BlockMonitor:Recorded pending call 26 in block 5057198: remove_stake - Coldkey: 5DL8qvmRdbx9sRHDPu5BSoMu2QLEMa7ta1c7YeRVb6h1XsQQ, Hotkey: 5DM9R1Y52rcKYCRMZr4twCzauA5Rz48rd2AvktwiyF2dQM4q, Call Amount: 0.410861439, Netuid: 1
# INFO:BlockMonitor:Recorded pending call 27 in block 5057198: add_stake - Coldkey: 5G9zepDQkiQpZnMggYsYnqee2BgtdwCqheNaHtZ1kqa2rzXj, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Call Amount: 2.0, Netuid: 70
# INFO:BlockMonitor:Recorded pending call 28 in block 5057198: add_stake - Coldkey: 5HKisem4LaHytpZ79wGhAXFGSt3CWdbaa5SnMn3haYbQiVDN, Hotkey: 5F2CsUDVbRbVMXTh9fAzF9GacjVX7UapvRxidrxe7z8BYckQ, Call Amount: 0.00055, Netuid: 24
# INFO:BlockMonitor:Recorded pending call 29 in block 5057198: remove_stake - Coldkey: 5DFdzQ3LBsrX4m8zEs7tiyqcd75pnh8smgNoTph94nkrMn86, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Call Amount: 0.700719975, Netuid: 71
# INFO:BlockMonitor:Recorded pending call 30 in block 5057198: remove_stake - Coldkey: 5EjzmUXfuVBJpy7AcHGDTJGroAPCDeyvgsLdvYmhzSKt75jm, Hotkey: 5D32XoxPwerFSY7Nk2jP4tNRqGZoyex8Djq3ZXFv6CCLobzR, Call Amount: 0.205794537, Netuid: 0
# INFO:BlockMonitor:Processing events for block 5057198
# INFO:BlockMonitor:Event 36 in block 5057198: StakeRemoved - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 4.022264436, Netuid: 70
# INFO:BlockMonitor:Event 38 in block 5057198: StakeRemoved - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.0, Netuid: 70
# INFO:BlockMonitor:Event 55 in block 5057198: StakeRemoved - Hotkey: 5Deo9Q3SnZWNPSEPRTgapbyy6egKu2oaNSqD4RQHHJEuzD9Y, Event Amount: 0.468418769, Netuid: 0
# INFO:BlockMonitor:Event 57 in block 5057198: StakeRemoved - Hotkey: 5Deo9Q3SnZWNPSEPRTgapbyy6egKu2oaNSqD4RQHHJEuzD9Y, Event Amount: 0.051507666, Netuid: 0
# INFO:BlockMonitor:Event 61 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.117116666, Netuid: 19
# INFO:BlockMonitor:Event 64 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.135262002, Netuid: 10
# INFO:BlockMonitor:Event 67 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.135272075, Netuid: 13
# INFO:BlockMonitor:Event 70 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.135282342, Netuid: 44
# INFO:BlockMonitor:Event 73 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.135290691, Netuid: 59
# INFO:BlockMonitor:Event 76 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.135339073, Netuid: 70
# INFO:BlockMonitor:Event 79 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.234283333, Netuid: 64
# INFO:BlockMonitor:Event 82 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.235067056, Netuid: 1
# INFO:BlockMonitor:Event 85 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.270680257, Netuid: 42
# INFO:BlockMonitor:Event 88 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.360119411, Netuid: 68
# INFO:BlockMonitor:Event 91 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.585783333, Netuid: 9
# INFO:BlockMonitor:Event 94 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.676966496, Netuid: 25
# INFO:BlockMonitor:Event 97 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.677233038, Netuid: 16
# INFO:BlockMonitor:Event 100 in block 5057198: StakeAdded - Hotkey: 5GKH9FPPnWSUoeeTJp19wVtd84XqFW4pyK2ijV2GsFbhTrP1, Event Amount: 0.677519748, Netuid: 37
# INFO:BlockMonitor:Event 107 in block 5057198: StakeAdded - Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Event Amount: 0.00055, Netuid: 5
# INFO:BlockMonitor:Validated pending call 24 (from block 5057198) with event StakeAdded in block 5057198: Coldkey: 5F9GPtA1ZZadPzFgF5MvunwxCcnCcHL8Zic1D2VDVfpSG67E, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Final Amount: 0.000550000, Fee: 4.9999999999999914e-05, Netuid: 5
# INFO:BlockMonitor:Event 111 in block 5057198: StakeAdded - Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Event Amount: 0.09995, Netuid: 51
# INFO:BlockMonitor:Validated pending call 25 (from block 5057198) with event StakeAdded in block 5057198: Coldkey: 5D72yvXBh52CXbKC83SDXyNFGhe6xgNDLxdKbDQKaTYumWaW, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Final Amount: 0.099950000, Fee: 5.000000000000837e-05, Netuid: 51
# INFO:BlockMonitor:Event 114 in block 5057198: StakeRemoved - Hotkey: 5DM9R1Y52rcKYCRMZr4twCzauA5Rz48rd2AvktwiyF2dQM4q, Event Amount: 0.013709427, Netuid: 1
# INFO:BlockMonitor:Validated pending call 26 (from block 5057198) with event StakeRemoved in block 5057198: Coldkey: 5DL8qvmRdbx9sRHDPu5BSoMu2QLEMa7ta1c7YeRVb6h1XsQQ, Hotkey: 5DM9R1Y52rcKYCRMZr4twCzauA5Rz48rd2AvktwiyF2dQM4q, Final Amount: 0.410861439, Netuid: 1
# INFO:BlockMonitor:Event 119 in block 5057198: StakeAdded - Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Event Amount: 1.99995, Netuid: 70
# INFO:BlockMonitor:Validated pending call 27 (from block 5057198) with event StakeAdded in block 5057198: Coldkey: 5G9zepDQkiQpZnMggYsYnqee2BgtdwCqheNaHtZ1kqa2rzXj, Hotkey: 5HEo565WAy4Dbq3Sv271SAi7syBSofyfhhwRNjFNSM2gP9M2, Final Amount: 1.999950000, Fee: 5.0000000000105516e-05, Netuid: 70
# INFO:BlockMonitor:Event 123 in block 5057198: StakeAdded - Hotkey: 5F2CsUDVbRbVMXTh9fAzF9GacjVX7UapvRxidrxe7z8BYckQ, Event Amount: 0.0005, Netuid: 24
# INFO:BlockMonitor:Validated pending call 28 (from block 5057198) with event StakeAdded in block 5057198: Coldkey: 5HKisem4LaHytpZ79wGhAXFGSt3CWdbaa5SnMn3haYbQiVDN, Hotkey: 5F2CsUDVbRbVMXTh9fAzF9GacjVX7UapvRxidrxe7z8BYckQ, Final Amount: 0.000500000, Fee: 5.000000000000002e-05, Netuid: 24
# INFO:BlockMonitor:Event 126 in block 5057198: StakeRemoved - Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Event Amount: 0.009942143, Netuid: 71
# INFO:BlockMonitor:Validated pending call 29 (from block 5057198) with event StakeRemoved in block 5057198: Coldkey: 5DFdzQ3LBsrX4m8zEs7tiyqcd75pnh8smgNoTph94nkrMn86, Hotkey: 5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3, Final Amount: 0.700719975, Netuid: 71
# INFO:BlockMonitor:Event 135 in block 5057198: StakeRemoved - Hotkey: 5D32XoxPwerFSY7Nk2jP4tNRqGZoyex8Djq3ZXFv6CCLobzR, Event Amount: 0.205744537, Netuid: 0
# INFO:BlockMonitor:Validated pending call 30 (from block 5057198) with event StakeRemoved in block 5057198: Coldkey: 5EjzmUXfuVBJpy7AcHGDTJGroAPCDeyvgsLdvYmhzSKt75jm, Hotkey: 5D32XoxPwerFSY7Nk2jP4tNRqGZoyex8Djq3ZXFv6CCLobzR, Final Amount: 0.205794537, Netuid: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 233
#     231 # Set verbose=True to print full raw extrinsic and event data.
#     232 monitor = BlockMonitor(substrate, logger, verbose=False)
# --> 233 monitor.start_monitoring()
#
# Cell In[52], line 213, in BlockMonitor.start_monitoring(self)
#     211 def start_monitoring(self):
#     212     self.logger.info(f"Starting block monitoring at {self.substrate.url}")
# --> 213     subscription = self.substrate.subscribe_block_headers(self.block_header_handler)
#     214     try:
#     215         while not self.should_exit:
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/substrateinterface/base.py:2586, in SubstrateInterface.subscribe_block_headers(self, subscription_handler, ignore_decoding_errors, include_author, finalized_only)
#    2583 else:
#    2584     block_hash = self.get_chain_head()
# -> 2586 return self.__get_block_handler(
#    2587     block_hash, subscription_handler=subscription_handler, ignore_decoding_errors=ignore_decoding_errors,
#    2588     include_author=include_author, finalized_only=finalized_only
#    2589 )
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/substrateinterface/base.py:2439, in SubstrateInterface.__get_block_handler(self, block_hash, ignore_decoding_errors, include_author, header_only, finalized_only, subscription_handler)
#    2435             self.rpc_request(f"chain_unsubscribe{rpc_method_prefix}Heads", [subscription_id])
#    2437         return subscription_result
# -> 2439     result = self.rpc_request(f"chain_subscribe{rpc_method_prefix}Heads", [], result_handler=result_handler)
#    2441     return result
#    2443 else:
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/substrateinterface/base.py:329, in SubstrateInterface.rpc_request(self, method, params, result_handler)
#     327         # Read one more message to queue
#     328         if json_body is None:
# --> 329             self.__rpc_message_queue.append(json.loads(self.websocket.recv()))
#     331 else:
#     333     if result_handler:
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:388, in WebSocket.recv(self)
#     380 """
#     381 Receive string data(byte array) from the server.
#     382
#    (...)
#     385 data: string (byte array) value.
#     386 """
#     387 with self.readlock:
# --> 388     opcode, data = self.recv_data()
#     389 if opcode == ABNF.OPCODE_TEXT:
#     390     data_received: Union[bytes, str] = data
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:416, in WebSocket.recv_data(self, control_frame)
#     401 def recv_data(self, control_frame: bool = False) -> tuple:
#     402     """
#     403     Receive data with operation code.
#     404
#    (...)
#     414         tuple of operation code and string(byte array) value.
#     415     """
# --> 416     opcode, frame = self.recv_data_frame(control_frame)
#     417     return opcode, frame.data
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:437, in WebSocket.recv_data_frame(self, control_frame)
#     420 """
#     421 Receive data with operation code.
#     422
#    (...)
#     434     tuple of operation code and string(byte array) value.
#     435 """
#     436 while True:
# --> 437     frame = self.recv_frame()
#     438     if isEnabledForTrace():
#     439         trace(f"++Rcv raw: {repr(frame.format())}")
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:478, in WebSocket.recv_frame(self)
#     470 def recv_frame(self):
#     471     """
#     472     Receive data as frame from server.
#     473
#    (...)
#     476     self.frame_buffer.recv_frame(): ABNF frame object
#     477     """
# --> 478     return self.frame_buffer.recv_frame()
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_abnf.py:363, in frame_buffer.recv_frame(self)
#     360 with self.lock:
#     361     # Header
#     362     if self.has_received_header():
# --> 363         self.recv_header()
#     364     (fin, rsv1, rsv2, rsv3, opcode, has_mask, _) = self.header
#     366     # Frame length
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_abnf.py:319, in frame_buffer.recv_header(self)
#     318 def recv_header(self) -> None:
# --> 319     header = self.recv_strict(2)
#     320     b1 = header[0]
#     321     fin = b1 >> 7 & 1
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_abnf.py:398, in frame_buffer.recv_strict(self, bufsize)
#     390 shortage = bufsize - sum(map(len, self.recv_buffer))
#     391 while shortage > 0:
#     392     # Limit buffer size that we pass to socket.recv() to avoid
#     393     # fragmenting the heap -- the number of bytes recv() actually
#    (...)
#     396     # buffers allocated and then shrunk, which results in
#     397     # fragmentation.
# --> 398     bytes_ = self.recv(min(16384, shortage))
#     399     self.recv_buffer.append(bytes_)
#     400     shortage -= len(bytes_)
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:563, in WebSocket._recv(self, bufsize)
#     561 def _recv(self, bufsize):
#     562     try:
# --> 563         return recv(self.sock, bufsize)
#     564     except WebSocketConnectionClosedException:
#     565         if self.sock:
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_socket.py:118, in recv(sock, bufsize)
#     116         bytes_ = sock.recv(bufsize)
#     117     else:
# --> 118         bytes_ = _recv()
#     119 except TimeoutError:
#     120     raise WebSocketTimeoutException("Connection timed out")
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_socket.py:97, in recv.<locals>._recv()
#      95 def _recv():
#      96     try:
# ---> 97         return sock.recv(bufsize)
#      98     except SSLWantReadError:
#      99         pass
#
# File /usr/lib/python3.10/ssl.py:1288, in SSLSocket.recv(self, buflen, flags)
#    1284     if flags != 0:
#    1285         raise ValueError(
#    1286             "non-zero flags not allowed in calls to recv() on %s" %
#    1287             self.__class__)
# -> 1288     return self.read(buflen)
#    1289 else:
#    1290     return super().recv(buflen, flags)
#
# File /usr/lib/python3.10/ssl.py:1161, in SSLSocket.read(self, len, buffer)
#    1159         return self._sslobj.read(len, buffer)
#    1160     else:
# -> 1161         return self._sslobj.read(len)
#    1162 except SSLError as x:
#    1163     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
from substrateinterface import SubstrateInterface

# Initialize the Substrate interface.
substrate = SubstrateInterface(
    url="wss://entrypoint-finney.opentensor.ai:443"
)

def block_header_handler(block_header, update_nr, subscription_id):
    # Extract the block hash from the header.
    block_hash = block_header.get("header", {}).get("hash")
    print("\nNew block received with hash:", block_hash)
    try:
        # Query the decoded events for this block.
        events_decoded = substrate.query("System", "Events", block_hash=block_hash)
        print("Decoded System.Events for block", block_hash, ":")
        for idx, event_record in enumerate(events_decoded.value):
            print(f"Event {idx}: {event_record}")
    except Exception as e:
        print("Error querying events for block", block_hash, ":", e)

# Subscribe to new block headers.
subscription = substrate.subscribe_block_headers(block_header_handler)
# Out:
# New block received with hash: None
# Decoded System.Events for block None :
# Event 0: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 39)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 39), 'topics': []}
# Event 1: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 2)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 2), 'topics': []}
# Event 2: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 55)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 55), 'topics': []}
# Event 3: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 1)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 1), 'topics': []}
# Event 4: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 239)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 239), 'topics': []}
# Event 5: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 233)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 233), 'topics': []}
# Event 6: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 229)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 229), 'topics': []}
# Event 7: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 228)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 228), 'topics': []}
# Event 8: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 39)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 39), 'topics': []}
# Event 9: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 2)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 2), 'topics': []}
# Event 10: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 239)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 239), 'topics': []}
# Event 11: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 55)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 55), 'topics': []}
# Event 12: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 203)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 203), 'topics': []}
# Event 13: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 1)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 1), 'topics': []}
# Event 14: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 233)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 233), 'topics': []}
# Event 15: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 239)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 239), 'topics': []}
# Event 16: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 39)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 39), 'topics': []}
# Event 17: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 2)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 2), 'topics': []}
# Event 18: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 55)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 55), 'topics': []}
# Event 19: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 96)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 96), 'topics': []}
# Event 20: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 229)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (41, 229), 'topics': []}
# Event 21: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 0, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 265758000, 'proof_size': 1493}, 'class': 'Mandatory', 'pays_fee': 'Yes'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 265758000, 'proof_size': 1493}, 'class': 'Mandatory', 'pays_fee': 'Yes'}}, 'topics': []}
# Event 22: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 1, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (38, 33)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (38, 33), 'topics': []}
# Event 23: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 1, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5CsvRJXuR955WojnGMdok1hbhffZyB4N5ocrv82f3p5A2zVp', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5CsvRJXuR955WojnGMdok1hbhffZyB4N5ocrv82f3p5A2zVp', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 24: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 1, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 125017074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 125017074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}, 'topics': []}
# Event 25: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 2, 'event': {'event_index': '074e', 'module_id': 'SubtensorModule', 'event_id': 'CRV3WeightsCommitted', 'attributes': ('5DZfWwTE4F4KRZFTbbvErwPUo26x3EuZymTvqb8VBmAvUd1f', 40, '0x18b57a199e069399fbca643d8d9f1f435af0252a39773a9b542f0602800e5e9d')}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'CRV3WeightsCommitted', 'attributes': ('5DZfWwTE4F4KRZFTbbvErwPUo26x3EuZymTvqb8VBmAvUd1f', 40, '0x18b57a199e069399fbca643d8d9f1f435af0252a39773a9b542f0602800e5e9d'), 'topics': []}
# Event 26: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 2, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5DZfWwTE4F4KRZFTbbvErwPUo26x3EuZymTvqb8VBmAvUd1f', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5DZfWwTE4F4KRZFTbbvErwPUo26x3EuZymTvqb8VBmAvUd1f', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 27: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 2, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 278074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 278074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}, 'topics': []}
# Event 28: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 3, 'event': {'event_index': '074e', 'module_id': 'SubtensorModule', 'event_id': 'CRV3WeightsCommitted', 'attributes': ('5G1NjW9YhXLadMWajvTkfcJy6up3yH2q1YzMXDTi6ijanChe', 58, '0x30627fe1751aa1b6febe14bc51737423c310ea5128c2845127e3f372e52097eb')}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'CRV3WeightsCommitted', 'attributes': ('5G1NjW9YhXLadMWajvTkfcJy6up3yH2q1YzMXDTi6ijanChe', 58, '0x30627fe1751aa1b6febe14bc51737423c310ea5128c2845127e3f372e52097eb'), 'topics': []}
# Event 29: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 3, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '
F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3', 18840963, 489189955, 10), 'topics': []}
# Event 69: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 18, 'event': {'event_index': '0704', 'module_id': 'SubtensorModule', 'event_id': 'StakeMoved', 'attributes': ('5FjmQqMEhqddxv5WGaE8XzZfoNtXYg6a7knovwckpkXr8X55', '5CPPYr53WzRtsT2xPHLFqeZXSTmNhA6CRAqTgKrEirA2HQp5', 10, '5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3', 10, 18840963)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'StakeMoved', 'attributes': ('5FjmQqMEhqddxv5WGaE8XzZfoNtXYg6a7knovwckpkXr8X55', '5CPPYr53WzRtsT2xPHLFqeZXSTmNhA6CRAqTgKrEirA2HQp5', 10, '5F4tQyWrhfGVcNhoqeiNsR6KjD4wMZ2kfhLj4oHYuyHbZAc3', 10, 18840963), 'topics': []}
# Event 70: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 18, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5FjmQqMEhqddxv5WGaE8XzZfoNtXYg6a7knovwckpkXr8X55', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5FjmQqMEhqddxv5WGaE8XzZfoNtXYg6a7knovwckpkXr8X55', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 71: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 18, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 210074000, 'proof_size': 0}, 'class': 'Operational', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 210074000, 'proof_size': 0}, 'class': 'Operational', 'pays_fee': 'No'}}, 'topics': []}
# Event 72: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 19, 'event': {'event_index': '1200', 'module_id': 'Commitments', 'event_id': 'Commitment', 'attributes': {'netuid': 68, 'who': '5DtkEik7venER21LWv8qe9LLuL8sadyJFw2p2D3Ng7fhQ4Ms'}}, 'event_index': 18, 'module_id': 'Commitments', 'event_id': 'Commitment', 'attributes': {'netuid': 68, 'who': '5DtkEik7venER21LWv8qe9LLuL8sadyJFw2p2D3Ng7fhQ4Ms'}, 'topics': []}
# Event 73: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 19, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5DtkEik7venER21LWv8qe9LLuL8sadyJFw2p2D3Ng7fhQ4Ms', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5DtkEik7venER21LWv8qe9LLuL8sadyJFw2p2D3Ng7fhQ4Ms', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 74: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 19, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}, 'topics': []}
# Event 75: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 20, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5HRNaBjhYUJvdU76ES8fvLLc4YWnkDohBwMXhVYvUMNNCbBo', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5HRNaBjhYUJvdU76ES8fvLLc4YWnkDohBwMXhVYvUMNNCbBo', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 76: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 20, 'event': {'event_index': '0001', 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 7, 'error': '0x25000000'}}, 'dispatch_info': {'weight': {'ref_time': 3334074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 7, 'error': '0x25000000'}}, 'dispatch_info': {'weight': {'ref_time': 3334074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}, 'topics': []}
# Event 77: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 21, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5Fq4gCshJLT15CXNL93uqUmTsL3j4wiN4XduJRTWQbee8EQS', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5Fq4gCshJLT15CXNL93uqUmTsL3j4wiN4XduJRTWQbee8EQS', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 78: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 21, 'event': {'event_index': '0001', 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}, 'topics': []}
# Event 79: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 22, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5GhSTYnYhBxaixz7EX5CUgP51hif8sTeaAHm98XB3ddDJ3p5', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5GhSTYnYhBxaixz7EX5CUgP51hif8sTeaAHm98XB3ddDJ3p5', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 80: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 22, 'event': {'event_index': '0001', 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 7, 'error': '0x25000000'}}, 'dispatch_info': {'weight': {'ref_time': 3334074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 7, 'error': '0x25000000'}}, 'dispatch_info': {'weight': {'ref_time': 3334074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}, 'topics': []}
# Event 81: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 23, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5E22Lm2JhzdvqW2v1xNALToCZqTvKwZWTwGWtMQmvonJwDys', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5E22Lm2JhzdvqW2v1xNALToCZqTvKwZWTwGWtMQmvonJwDys', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 82: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 23, 'event': {'event_index': '0001', 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}, 'topics': []}
# Event 83: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 24, 'event': {'event_index': '0703', 'module_id': 'SubtensorModule', 'event_id': 'StakeRemoved', 'attributes': ('5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', '5EX4ufGWrAh3gBPWQY6Lsqr4bcFDsh6qNp3qLLy4XdCjFiZH', 617721276, 17763195019, 68)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'StakeRemoved', 'attributes': ('5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', '5EX4ufGWrAh3gBPWQY6Lsqr4bcFDsh6qNp3qLLy4XdCjFiZH', 617721276, 17763195019, 68), 'topics': []}
# Event 84: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 24, 'event': {'event_index': '0507', 'module_id': 'Balances', 'event_id': 'Deposit', 'attributes': {'who': '5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', 'amount': 617721276}}, 'event_index': 5, 'module_id': 'Balances', 'event_id': 'Deposit', 'attributes': {'who': '5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', 'amount': 617721276}, 'topics': []}
# Event 85: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 24, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 86: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 24, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 1168074000, 'proof_size': 43991}, 'class': 'Normal', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 1168074000, 'proof_size': 43991}, 'class': 'Normal', 'pays_fee': 'No'}}, 'topics': []}
# Event 87: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 25, 'event': {'event_index': '1a01', 'module_id': 'Drand', 'event_id': 'NewPulse', 'attributes': {'rounds': [16105852, 16105853, 16105854, 16105855, 16105856, 16105857, 16105858, 16105859]}}, 'event_index': 26, 'module_id': 'Drand', 'event_id': 'NewPulse', 'attributes': {'rounds': [16105852, 16105853, 16105854, 16105855, 16105856, 16105857, 16105858, 16105859]}, 'topics': []}
# Event 88: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 25, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 980074000, 'proof_size': 13784}, 'class': 'Normal', 'pays_fee': 'Yes'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 980074000, 'proof_size': 13784}, 'class': 'Normal', 'pays_fee': 'Yes'}}, 'topics': []}
#
# New block received with hash: None
# Decoded System.Events for block None :
# Event 0: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '070b', 'module_id': 'SubtensorModule', 'event_id': 'DifficultySet', 'attributes': (49, 210317146182672107)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'DifficultySet', 'attributes': (49, 210317146182672107), 'topics': []}
# Event 1: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 245)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 245), 'topics': []}
# Event 2: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 20)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 20), 'topics': []}
# Event 3: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 250)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 250), 'topics': []}
# Event 4: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 254)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 254), 'topics': []}
# Event 5: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 11)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 11), 'topics': []}
# Event 6: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 24)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 24), 'topics': []}
# Event 7: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 245)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 245), 'topics': []}
# Event 8: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 250)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 250), 'topics': []}
# Event 9: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 20)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 20), 'topics': []}
# Event 10: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 254)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 254), 'topics': []}
# Event 11: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 11)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 11), 'topics': []}
# Event 12: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 245)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 245), 'topics': []}
# Event 13: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 250)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 250), 'topics': []}
# Event 14: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 20)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 20), 'topics': []}
# Event 15: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 155)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 155), 'topics': []}
# Event 16: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 3)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 3), 'topics': []}
# Event 17: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 254)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 254), 'topics': []}
# Event 18: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 11)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 11), 'topics': []}
# Event 19: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 245)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 245), 'topics': []}
# Event 20: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 231)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 231), 'topics': []}
# Event 21: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 24)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 24), 'topics': []}
# Event 22: {'phase': 'Initialization', 'extrinsic_idx': None, 'event': {'event_index': '0705', 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 20)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'WeightsSet', 'attributes': (40, 20), 'topics': []}
# Event 23: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 0, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 265758000, 'proof_size': 1493}, 'class': 'Mandatory', 'pays_fee': 'Yes'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 265758000, 'proof_size': 1493}, 'class': 'Mandatory', 'pays_fee': 'Yes'}}, 'topics': []}
# ...
# Event 73: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 26, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 353074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 353074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}, 'topics': []}
# Event 74: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 27, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5G6EMhcCSUCRHM8k7JgKDeJb759rMdNcZoKNzUXwo1XTfLsZ', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5G6EMhcCSUCRHM8k7JgKDeJb759rMdNcZoKNzUXwo1XTfLsZ', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 75: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 27, 'event': {'event_index': '0001', 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}, 'topics': []}
# Event 76: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 28, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5EHHBcXhzzgq8i5QNyvy9iTjY6jZS4tT3FKHRh5LTeoDPnMH', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5EHHBcXhzzgq8i5QNyvy9iTjY6jZS4tT3FKHRh5LTeoDPnMH', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 77: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 28, 'event': {'event_index': '0001', 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}, 'topics': []}
# Event 78: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 29, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5E22Lm2JhzdvqW2v1xNALToCZqTvKwZWTwGWtMQmvonJwDys', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5E22Lm2JhzdvqW2v1xNALToCZqTvKwZWTwGWtMQmvonJwDys', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 79: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 29, 'event': {'event_index': '0001', 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}, 'topics': []}
# Event 80: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 30, 'event': {'event_index': '0703', 'module_id': 'SubtensorModule', 'event_id': 'StakeRemoved', 'attributes': ('5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', '5CDMARvs16y9EmPMpeRPuCo73Skirtfbz7Eo26U9Lx3pgbdN', 85073570, 21549281101, 69)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'StakeRemoved', 'attributes': ('5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', '5CDMARvs16y9EmPMpeRPuCo73Skirtfbz7Eo26U9Lx3pgbdN', 85073570, 21549281101, 69), 'topics': []}
# Event 81: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 30, 'event': {'event_index': '0507', 'module_id': 'Balances', 'event_id': 'Deposit', 'attributes': {'who': '5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', 'amount': 85073570}}, 'event_index': 5, 'module_id': 'Balances', 'event_id': 'Deposit', 'attributes': {'who': '5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', 'amount': 85073570}, 'topics': []}
# Event 82: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 30, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5CATacb2QQaJWpDxBRdmyitupUs3YpLNupG2iKXVTsY18ycc', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 83: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 30, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 1168074000, 'proof_size': 43991}, 'class': 'Normal', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 1168074000, 'proof_size': 43991}, 'class': 'Normal', 'pays_fee': 'No'}}, 'topics': []}
# Event 84: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 31, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5GFErhCxAMtDT5b87qoMcBKaTFn1yNm9cM9z1j5aXqaYMWhV', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5GFErhCxAMtDT5b87qoMcBKaTFn1yNm9cM9z1j5aXqaYMWhV', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 85: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 31, 'event': {'event_index': '0001', 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicFailed', 'attributes': {'dispatch_error': {'Module': {'index': 18, 'error': '0x02000000'}}, 'dispatch_info': {'weight': {'ref_time': 385074000, 'proof_size': 6344}, 'class': 'Operational', 'pays_fee': 'No'}}, 'topics': []}
# Event 86: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 32, 'event': {'event_index': '0508', 'module_id': 'Balances', 'event_id': 'Withdraw', 'attributes': {'who': '5Ea8Zao2hapc6dH7goAjrc5XYsUJPgEhcwXwxzdSSYi43SED', 'amount': 48180087}}, 'event_index': 5, 'module_id': 'Balances', 'event_id': 'Withdraw', 'attributes': {'who': '5Ea8Zao2hapc6dH7goAjrc5XYsUJPgEhcwXwxzdSSYi43SED', 'amount': 48180087}, 'topics': []}
# Event 87: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 32, 'event': {'event_index': '0730', 'module_id': 'SubtensorModule', 'event_id': 'RAORecycledForRegistrationSet', 'attributes': (1, 96958523350525)}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'RAORecycledForRegistrationSet', 'attributes': (1, 96958523350525), 'topics': []}
# Event 88: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 32, 'event': {'event_index': '0706', 'module_id': 'SubtensorModule', 'event_id': 'NeuronRegistered', 'attributes': (1, 306, '5GNakbw5irQyZmammqMhFv3U9oCVmUEDf6bxoYUimKUbniri')}, 'event_index': 7, 'module_id': 'SubtensorModule', 'event_id': 'NeuronRegistered', 'attributes': (1, 306, '5GNakbw5irQyZmammqMhFv3U9oCVmUEDf6bxoYUimKUbniri'), 'topics': []}
# Event 89: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 32, 'event': {'event_index': '0600', 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5Ea8Zao2hapc6dH7goAjrc5XYsUJPgEhcwXwxzdSSYi43SED', 'actual_fee': 0, 'tip': 0}}, 'event_index': 6, 'module_id': 'TransactionPayment', 'event_id': 'TransactionFeePaid', 'attributes': {'who': '5Ea8Zao2hapc6dH7goAjrc5XYsUJPgEhcwXwxzdSSYi43SED', 'actual_fee': 0, 'tip': 0}, 'topics': []}
# Event 90: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 32, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 3334074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 3334074000, 'proof_size': 0}, 'class': 'Normal', 'pays_fee': 'No'}}, 'topics': []}
# Event 91: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 33, 'event': {'event_index': '1a01', 'module_id': 'Drand', 'event_id': 'NewPulse', 'attributes': {'rounds': [16105876, 16105877, 16105878, 16105879, 16105880, 16105881, 16105882, 16105883]}}, 'event_index': 26, 'module_id': 'Drand', 'event_id': 'NewPulse', 'attributes': {'rounds': [16105876, 16105877, 16105878, 16105879, 16105880, 16105881, 16105882, 16105883]}, 'topics': []}
# Event 92: {'phase': 'ApplyExtrinsic', 'extrinsic_idx': 33, 'event': {'event_index': '0000', 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 980074000, 'proof_size': 13784}, 'class': 'Normal', 'pays_fee': 'Yes'}}}, 'event_index': 0, 'module_id': 'System', 'event_id': 'ExtrinsicSuccess', 'attributes': {'dispatch_info': {'weight': {'ref_time': 980074000, 'proof_size': 13784}, 'class': 'Normal', 'pays_fee': 'Yes'}}, 'topics': []}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 22
#      19         print("Error querying events for block", block_hash, ":", e)
#      21 # Subscribe to new block headers.
# ---> 22 subscription = substrate.subscribe_block_headers(block_header_handler)
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/substrateinterface/base.py:2586, in SubstrateInterface.subscribe_block_headers(self, subscription_handler, ignore_decoding_errors, include_author, finalized_only)
#    2583 else:
#    2584     block_hash = self.get_chain_head()
# -> 2586 return self.__get_block_handler(
#    2587     block_hash, subscription_handler=subscription_handler, ignore_decoding_errors=ignore_decoding_errors,
#    2588     include_author=include_author, finalized_only=finalized_only
#    2589 )
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/substrateinterface/base.py:2439, in SubstrateInterface.__get_block_handler(self, block_hash, ignore_decoding_errors, include_author, header_only, finalized_only, subscription_handler)
#    2435             self.rpc_request(f"chain_unsubscribe{rpc_method_prefix}Heads", [subscription_id])
#    2437         return subscription_result
# -> 2439     result = self.rpc_request(f"chain_subscribe{rpc_method_prefix}Heads", [], result_handler=result_handler)
#    2441     return result
#    2443 else:
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/substrateinterface/base.py:329, in SubstrateInterface.rpc_request(self, method, params, result_handler)
#     327         # Read one more message to queue
#     328         if json_body is None:
# --> 329             self.__rpc_message_queue.append(json.loads(self.websocket.recv()))
#     331 else:
#     333     if result_handler:
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:388, in WebSocket.recv(self)
#     380 """
#     381 Receive string data(byte array) from the server.
#     382
#    (...)
#     385 data: string (byte array) value.
#     386 """
#     387 with self.readlock:
# --> 388     opcode, data = self.recv_data()
#     389 if opcode == ABNF.OPCODE_TEXT:
#     390     data_received: Union[bytes, str] = data
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:416, in WebSocket.recv_data(self, control_frame)
#     401 def recv_data(self, control_frame: bool = False) -> tuple:
#     402     """
#     403     Receive data with operation code.
#     404
#    (...)
#     414         tuple of operation code and string(byte array) value.
#     415     """
# --> 416     opcode, frame = self.recv_data_frame(control_frame)
#     417     return opcode, frame.data
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:437, in WebSocket.recv_data_frame(self, control_frame)
#     420 """
#     421 Receive data with operation code.
#     422
#    (...)
#     434     tuple of operation code and string(byte array) value.
#     435 """
#     436 while True:
# --> 437     frame = self.recv_frame()
#     438     if isEnabledForTrace():
#     439         trace(f"++Rcv raw: {repr(frame.format())}")
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:478, in WebSocket.recv_frame(self)
#     470 def recv_frame(self):
#     471     """
#     472     Receive data as frame from server.
#     473
#    (...)
#     476     self.frame_buffer.recv_frame(): ABNF frame object
#     477     """
# --> 478     return self.frame_buffer.recv_frame()
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_abnf.py:363, in frame_buffer.recv_frame(self)
#     360 with self.lock:
#     361     # Header
#     362     if self.has_received_header():
# --> 363         self.recv_header()
#     364     (fin, rsv1, rsv2, rsv3, opcode, has_mask, _) = self.header
#     366     # Frame length
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_abnf.py:319, in frame_buffer.recv_header(self)
#     318 def recv_header(self) -> None:
# --> 319     header = self.recv_strict(2)
#     320     b1 = header[0]
#     321     fin = b1 >> 7 & 1
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_abnf.py:398, in frame_buffer.recv_strict(self, bufsize)
#     390 shortage = bufsize - sum(map(len, self.recv_buffer))
#     391 while shortage > 0:
#     392     # Limit buffer size that we pass to socket.recv() to avoid
#     393     # fragmenting the heap -- the number of bytes recv() actually
#    (...)
#     396     # buffers allocated and then shrunk, which results in
#     397     # fragmentation.
# --> 398     bytes_ = self.recv(min(16384, shortage))
#     399     self.recv_buffer.append(bytes_)
#     400     shortage -= len(bytes_)
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_core.py:563, in WebSocket._recv(self, bufsize)
#     561 def _recv(self, bufsize):
#     562     try:
# --> 563         return recv(self.sock, bufsize)
#     564     except WebSocketConnectionClosedException:
#     565         if self.sock:
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_socket.py:118, in recv(sock, bufsize)
#     116         bytes_ = sock.recv(bufsize)
#     117     else:
# --> 118         bytes_ = _recv()
#     119 except TimeoutError:
#     120     raise WebSocketTimeoutException("Connection timed out")
#
# File ~/bettensor/.venv/lib/python3.10/site-packages/websocket/_socket.py:97, in recv.<locals>._recv()
#      95 def _recv():
#      96     try:
# ---> 97         return sock.recv(bufsize)
#      98     except SSLWantReadError:
#      99         pass
#
# File /usr/lib/python3.10/ssl.py:1288, in SSLSocket.recv(self, buflen, flags)
#    1284     if flags != 0:
#    1285         raise ValueError(
#    1286             "non-zero flags not allowed in calls to recv() on %s" %
#    1287             self.__class__)
# -> 1288     return self.read(buflen)
#    1289 else:
#    1290     return super().recv(buflen, flags)
#
# File /usr/lib/python3.10/ssl.py:1161, in SSLSocket.read(self, len, buffer)
#    1159         return self._sslobj.read(len, buffer)
#    1160     else:
# -> 1161         return self._sslobj.read(len)
#    1162 except SSLError as x:
#    1163     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
