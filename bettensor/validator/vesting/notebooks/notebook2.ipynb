# %% [markdown]
# # Bittensor Subtensor API Exploration for Stake Tracking
#
# This notebook explores various methods available in the Bittensor Subtensor class to track:
# 1. Current stake values
# 2. Stake transactions (add_stake/remove_stake)
# 3. Epoch boundaries
#
# The goal is to determine the most reliable methods to use in the vesting system's stake tracker.

# %%
# Import necessary libraries
import json
from datetime import datetime, timezone, timedelta
import time
import pandas as pd
import matplotlib.pyplot as plt
import bittensor as bt

# Configure display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## 1. Connect to Bittensor Network

# %%
# Connect to Bittensor
def connect_subtensor(network="finney"):
    """Connect to Bittensor and return a Subtensor instance"""
    print(f"Connecting to {network} network...")
    
    # Create a subtensor connection
    subtensor = bt.subtensor(network=network)
    
    # Test connection by getting current block
    current_block = subtensor.get_current_block()
    print(f"Connected successfully. Current block: {current_block}")
    
    return subtensor

subtensor = connect_subtensor()
# Out:
# Connecting to finney network...
# Connected successfully. Current block: 5055919

# %% [markdown]
# ## 2. Utility Functions for Pretty Printing

# %%
# Pretty print results
def print_result(result, title=None):
    """Pretty print a result"""
    if title:
        print(f"\n=== {title} ===\n")
    
    if isinstance(result, dict):
        print(json.dumps(result, indent=2, default=str))
    elif hasattr(result, '__dict__'):
        # For objects, try to convert to dict
        try:
            print(json.dumps(result.__dict__, indent=2, default=str))
        except:
            print(result)
    elif isinstance(result, list):
        if len(result) > 5:
            print(f"List with {len(result)} items. Showing first 5:")
            for item in result[:5]:
                if hasattr(item, '__dict__'):
                    try:
                        print(json.dumps(item.__dict__, indent=2, default=str))
                    except:
                        print(item)
                else:
                    print(item)
        else:
            for item in result:
                if hasattr(item, '__dict__'):
                    try:
                        print(json.dumps(item.__dict__, indent=2, default=str))
                    except:
                        print(item)
                else:
                    print(item)
    else:
        print(result)

# %% [markdown]
# ## 3. Examine Available Methods in Subtensor

# %%
# List all methods in Subtensor class related to stake, neurons, and subnets
all_methods = [method for method in dir(subtensor) if not method.startswith('_')]
filtered_methods = [method for method in all_methods 
                   if any(keyword in method.lower() 
                         for keyword in ['stake', 'neuron', 'subnet', 'validator', 'weight'])]

print(f"Found {len(filtered_methods)} relevant methods in Subtensor class:")
for method in sorted(filtered_methods):
    print(f"- {method}")
# Out:
# Found 43 relevant methods in Subtensor class:
# - add_stake
# - add_stake_multiple
# - all_subnets
# - commit_weights
# - get_all_neuron_certificates
# - get_all_subnets_info
# - get_current_weight_commit_info
# - get_hotkey_stake
# - get_minimum_required_stake
# - get_neuron_certificate
# - get_neuron_for_pubkey_and_subnet
# - get_stake
# - get_stake_for_coldkey
# - get_stake_for_coldkey_and_hotkey
# - get_stake_for_hotkey
# - get_stake_info_for_coldkey
# - get_subnet_burn_cost
# - get_subnet_hyperparameters
# - get_subnet_reveal_period_epochs
# - get_subnets
# - get_total_subnets
# - get_uid_for_hotkey_on_subnet
# - is_hotkey_registered_on_subnet
# - max_weight_limit
# - min_allowed_weights
# - move_stake
# - neuron_for_uid
# - neurons
# - neurons_lite
# - register_subnet
# - reveal_weights
# - root_set_weights
# - set_subnet_identity
# - set_weights
# - subnet
# - subnet_exists
# - subnetwork_n
# - swap_stake
# - transfer_stake
# - unstake
# - unstake_multiple
# - weights
# - weights_rate_limit

# %% [markdown]
# ## 4. Get Subnet Information

# %%
# Get subnets list
subnets = subtensor.get_subnets()
print(f"Found {len(subnets)} subnets")

# Display basic info for each subnet
for netuid in subnets:
    subnet_info = subtensor.subnet(netuid)
    print(subnet_info)

# Select a subnet for further exploration
# We'll use subnet 1 (typically the main Bittensor network) by default
NETUID = 30  # Change this to explore different subnets
# Out:
# Found 72 subnets
# DynamicInfo(netuid=0, owner_hotkey='5C4hrfjw9DjXZTzV3MwzrrAr9P1MJhSrvWGWqi1eSuyUpnhM', owner_coldkey='5C4hrfjw9DjXZTzV3MwzrrAr9P1MJhSrvWGWqi1eSuyUpnhM', subnet_name='root', symbol='Τ', tempo=100, last_step=4919910, blocks_since_last_step=136063, emission=τ0.000000000, alpha_in=τ71,482.498436642, alpha_out=τ5,979,130.859390919, tao_in=τ5,979,133.568963266, price=τ1.000000000, k=427403405995890363737726392772, is_dynamic=False, alpha_out_emission=τ0.000000000, alpha_in_emission=τ0.000000000, tao_in_emission=τ0.000000000, pending_alpha_emission=τ0.000000000, pending_root_emission=τ0.000000000, network_registered_at=0, subnet_volume=τ3,492,357.147528417, subnet_identity=None, moving_price=0.0)
# DynamicInfo(netuid=1, owner_hotkey='5HCFWvRqzSHWRPecN7q8J6c7aKQnrCZTMHstPv39xL1wgDHh', owner_coldkey='5HCFWvRqzSHWRPecN7q8J6c7aKQnrCZTMHstPv39xL1wgDHh', subnet_name='apex', symbol='α', tempo=99, last_step=5055897, blocks_since_last_step=76, emission=τ0.000000000, alpha_in=‎93,685.629143070α‎, alpha_out=‎129,982.692615662α‎, tao_in=τ3,140.275116497, price=τ0.033519283, k=294198649971348882530225790, is_dynamic=True, alpha_out_emission=‎1.000000000α‎, alpha_in_emission=‎0.666157366α‎, tao_in_emission=τ0.022329279, pending_alpha_emission=‎36.520461011α‎, pending_root_emission=τ0.863433000, network_registered_at=1497824, subnet_volume=‎20,705.149916737α‎, subnet_identity=SubnetIdentity(subnet_name='Apex', github_repo='https://github.com/macrocosm-os/prompting', subnet_contact='support@macrocosmos.ai', subnet_url='https://www.macrocosmos.ai/sn1', discord='macrocrux', description='Apex intelligence', additional=''), moving_price=7.290093387898183e-12)
# DynamicInfo(netuid=2, owner_hotkey='5CFxLBvpyQq3TCP7zLcu8dLcPBxhA6MdLvXiCyvJVojuK17J', owner_coldkey='5EcYQ3W77ndrmMWdvVQusoFqY8doxfP3U2zrh7xZQiaz7avY', subnet_name='omron', symbol='β', tempo=360, last_step=5055801, blocks_since_last_step=172, emission=τ0.000000000, alpha_in=‎130,846.638079185β‎, alpha_out=‎97,886.038655678β‎, tao_in=τ369.833313263, price=τ0.002826464, k=48391445690149610704730655, is_dynamic=True, alpha_out_emission=‎1.000000000β‎, alpha_in_emission=‎0.714228475β‎, tao_in_emission=τ0.002018751, pending_alpha_emission=‎82.872212225β‎, pending_root_emission=τ0.164484441, network_registered_at=2734060, subnet_volume=‎2,433.429154962β‎, subnet_identity=SubnetIdentity(subnet_name='omron 🥩', github_repo='https://github.com/inference-labs-inc/omron-subnet', subnet_contact='', subnet_url='https://omron.ai/', discord='', description='inference and compute verification marketplace and accelerator', additional=''), moving_price=6.590704002516767e-13)
# DynamicInfo(netuid=3, owner_hotkey='5HdTZQ6UXD7MWcRsMeExVwqAKKo4UwomUd662HvtXiZXkxmv', owner_coldkey='5G26HqQg8M6hfw9q84gM3udYHHymThmswRKgSGtwdcduBSos', subnet_name='templar', symbol='γ', tempo=360, last_step=5055800, blocks_since_last_step=173, emission=τ0.000000000, alpha_in=‎85,217.089805799γ‎, alpha_out=‎139,246.830027204γ‎, tao_in=τ2,219.689069843, price=τ0.026047463, k=189155442805761379817419557, is_dynamic=True, alpha_out_emission=‎1.000000000γ‎, alpha_in_emission=‎0.702606718γ‎, tao_in_emission=τ0.018301268, pending_alpha_emission=‎83.162028580γ‎, pending_root_emission=τ1.529723761, network_registered_at=4165565, subnet_volume=‎12,032.057223743γ‎, subnet_identity=None, moving_price=5.9749235181878746e-12)
# DynamicInfo(netuid=4, owner_hotkey='5CXGPMnq9RCCLUEvp9G2iUuabw69TSFM155UVS1S4Zmusaxv', owner_coldkey='5CXGPMnq9RCCLUEvp9G2iUuabw69TSFM155UVS1S4Zmusaxv', subnet_name='targon', symbol='δ', tempo=360, last_step=5055799, blocks_since_last_step=174, emission=τ0.000000000, alpha_in=‎90,730.480817871δ‎, alpha_out=‎128,058.158147651δ‎, tao_in=τ18,003.792735712, price=τ0.198431580, k=1633492771456442870309509152, is_dynamic=True, alpha_out_emission=‎1.000000000δ‎, alpha_in_emission=‎0.705344856δ‎, tao_in_emission=τ0.139963746, pending_alpha_emission=‎83.383990026δ‎, pending_root_emission=τ11.797722244, network_registered_at=1411451, subnet_volume=‎142,519.898345688δ‎, subnet_identity=None, moving_price=4.56947390624525e-11)
# DynamicInfo(netuid=5, owner_hotkey='5CFmgJ2SQZBjgdyDvwsWhAQatEENLt6k2gWvpkjeHeMm95yv', owner_coldkey='5CFmgJ2SQZBjgdyDvwsWhAQatEENLt6k2gWvpkjeHeMm95yv', subnet_name='kaito', symbol='ε', tempo=360, last_step=5055798, blocks_since_last_step=175, emission=τ0.000000000, alpha_in=‎126,001.354981925ε‎, alpha_out=‎101,748.333240486ε‎, tao_in=τ1,529.086141043, price=τ0.012135473, k=192666925655500881265647775, is_dynamic=True, alpha_out_emission=‎1.000000000ε‎, alpha_in_emission=‎0.726068313ε‎, tao_in_emission=τ0.008811230, pending_alpha_emission=‎84.272849014ε‎, pending_root_emission=τ0.718910465, network_registered_at=2491604, subnet_volume=‎11,070.432394167ε‎, subnet_identity=None, moving_price=2.876626183350578e-12)
# DynamicInfo(netuid=6, owner_hotkey='5CfSg4e23Z3aTXvc2XZie8ZE1xkqRPoyVRFdWUuyyjGxJrMA', owner_coldkey='5CfSg4e23Z3aTXvc2XZie8ZE1xkqRPoyVRFdWUuyyjGxJrMA', subnet_name='infinite', symbol='ζ', tempo=360, last_step=5055797, blocks_since_last_step=176, emission=τ0.000000000, alpha_in=‎115,414.335458839ζ‎, alpha_out=‎100,515.735156431ζ‎, tao_in=τ1,238.481739228, price=τ0.010730744, k=142938546910906756125636292, is_dynamic=True, alpha_out_emission=‎1.000000000ζ‎, alpha_in_emission=‎0.717440355ζ‎, tao_in_emission=τ0.007698714, pending_alpha_emission=‎84.209574613ζ‎, pending_root_emission=τ0.645374418, network_registered_at=3219949, subnet_volume=‎19,379.724115272ζ‎, subnet_identity=None, moving_price=2.5134290807492243e-12)
# DynamicInfo(netuid=7, owner_hotkey='5CiQ1cxLB1ABBJyf9FAR8CRhfcKgs4M8QaRgmHh318PKLqvb', owner_coldkey='5CiQ1cxLB1ABBJyf9FAR8CRhfcKgs4M8QaRgmHh318PKLqvb', subnet_name='subvortex', symbol='η', tempo=360, last_step=5055796, blocks_since_last_step=177, emission=τ0.000000000, alpha_in=‎98,913.018069091η‎, alpha_out=‎118,236.290928400η‎, tao_in=τ200.187741875, price=τ0.002023876, k=19801173729292400023885625, is_dynamic=True, alpha_out_emission=‎1.000000000η‎, alpha_in_emission=‎0.751306716η‎, tao_in_emission=τ0.001520562, pending_alpha_emission=‎84.744829103η‎, pending_root_emission=τ0.122407344, network_registered_at=2627691, subnet_volume=‎1,664.528701783η‎, subnet_identity=None, moving_price=4.96417143502903e-13)
# DynamicInfo(netuid=8, owner_hotkey='5F6tnxzAAxbhaWRmeUmB63JEM3VXBNSmqb3AwYJVDStQjw8y', owner_coldkey='5F6tnxzAAxbhaWRmeUmB63JEM3VXBNSmqb3AwYJVDStQjw8y', subnet_name='ptn', symbol='θ', tempo=360, last_step=5055795, blocks_since_last_step=178, emission=τ0.000000000, alpha_in=‎61,946.128481597θ‎, alpha_out=‎152,108.880049992θ‎, tao_in=τ12,146.162340757, price=τ0.196076213, k=752407732918868083717548929, is_dynamic=True, alpha_out_emission=‎1.000000000θ‎, alpha_in_emission=‎0.699596093θ‎, tao_in_emission=τ0.137175667, pending_alpha_emission=‎85.078154988θ‎, pending_root_emission=τ12.007025305, network_registered_at=1477264, subnet_volume=‎95,209.388184376θ‎, subnet_identity=None, moving_price=4.478461124082095e-11)
# DynamicInfo(netuid=9, owner_hotkey='5FsbubeciqtB5Nik3umL2iD4fG8FcC9GbT9nHJfXMj4mJJZ9', owner_coldkey='5FsbubeciqtB5Nik3umL2iD4fG8FcC9GbT9nHJfXMj4mJJZ9', subnet_name='pretrain', symbol='ι', tempo=360, last_step=5055794, blocks_since_last_step=179, emission=τ0.000000000, alpha_in=‎84,852.655459272ι‎, alpha_out=‎140,669.253498571ι‎, tao_in=τ1,892.945159899, price=τ0.022308614, k=160621423456206391322133528, is_dynamic=True, alpha_out_emission=‎1.000000000ι‎, alpha_in_emission=‎0.653528791ι‎, tao_in_emission=τ0.014579438, pending_alpha_emission=‎86.095520471ι‎, pending_root_emission=τ1.354918228, network_registered_at=1489797, subnet_volume=‎11,075.773872483ι‎, subnet_identity=SubnetIdentity(subnet_name='Pretrain', github_repo='https://github.com/macrocosm-os/pretraining', subnet_contact='support@macrocosmos.ai', subnet_url='https://www.macrocosmos.ai/sn9', discord='macrocrux', description='SOTA models built by Bittensor', additional=''), moving_price=4.759944337556082e-12)
# DynamicInfo(netuid=10, owner_hotkey='5EvNESR7DfSMmdwJ3crtBW1ENAhq3f99X4FCbTi1hDUNCWAW', owner_coldkey='5EvNESR7DfSMmdwJ3crtBW1ENAhq3f99X4FCbTi1hDUNCWAW', subnet_name='sturdy', symbol='κ', tempo=360, last_step=5055793, blocks_since_last_step=180, emission=τ0.000000000, alpha_in=‎92,140.601823666κ‎, alpha_out=‎132,636.158474865κ‎, tao_in=τ2,584.052478081, price=τ0.028044666, k=238096150474318835092064946, is_dynamic=True, alpha_out_emission=‎1.000000000κ‎, alpha_in_emission=‎0.529492606κ‎, tao_in_emission=τ0.014849552, pending_alpha_emission=‎86.542034237κ‎, pending_root_emission=τ1.714321868, network_registered_at=2869647, subnet_volume=‎19,730.494331121κ‎, subnet_identity=None, moving_price=4.848504139409043e-12)
# DynamicInfo(netuid=11, owner_hotkey='5EtM9iXMAYRsmt6aoQAoWNDX6yaBnjhmnEQhWKv8HpwkVtML', owner_coldkey='5EtM9iXMAYRsmt6aoQAoWNDX6yaBnjhmnEQhWKv8HpwkVtML', subnet_name='dippy', symbol='λ', tempo=360, last_step=5055792, blocks_since_last_step=181, emission=τ0.000000000, alpha_in=‎97,113.621532316λ‎, alpha_out=‎131,449.630380415λ‎, tao_in=τ2,434.981774582, price=τ0.025073534, k=236469898494843539740391912, is_dynamic=True, alpha_out_emission=‎1.000000000λ‎, alpha_in_emission=‎0.709322249λ‎, tao_in_emission=τ0.017785339, pending_alpha_emission=‎87.200162039λ‎, pending_root_emission=τ1.537339535, network_registered_at=2918568, subnet_volume=‎33,208.723893132λ‎, subnet_identity=None, moving_price=5.806468424563588e-12)
# DynamicInfo(netuid=12, owner_hotkey='5ELzhHvgUqmnAYs74vFWjMMehXNeHkRtkreAa3g8QQS96PCp', owner_coldkey='5ELzhHvgUqmnAYs74vFWjMMehXNeHkRtkreAa3g8QQS96PCp', subnet_name='horde', symbol='μ', tempo=360, last_step=5055791, blocks_since_last_step=182, emission=τ0.000000000, alpha_in=‎118,928.932131995μ‎, alpha_out=‎113,502.564791244μ‎, tao_in=τ423.918470004, price=τ0.003564468, k=50416170948604874176177980, is_dynamic=True, alpha_out_emission=‎1.000000000μ‎, alpha_in_emission=‎0.727301766μ‎, tao_in_emission=τ0.002592459, pending_alpha_emission=‎87.863747157μ‎, pending_root_emission=τ0.218788470, network_registered_at=2256433, subnet_volume=‎1,384.845250513μ‎, subnet_identity=None, moving_price=8.463666508091994e-13)
, alpha_out=‎107,605.458043871υ‎, tao_in=τ900.751423316, price=τ0.008388888, k=96717594904998640315163700, is_dynamic=True, alpha_out_emission=‎1.000000000υ‎, alpha_in_emission=‎0.722580422υ‎, tao_in_emission=τ0.006061685, pending_alpha_emission=‎90.859534108υ‎, pending_root_emission=τ0.544626602, network_registered_at=1970929, subnet_volume=‎5,526.761767089υ‎, subnet_identity=None, moving_price=1.978977528724335e-12)
# DynamicInfo(netuid=21, owner_hotkey='5GsHpHeCGhxstoEEZTR64VUashnDP4n7ir7LbNdRfXpkMU7R', owner_coldkey='5GsHpHeCGhxstoEEZTR64VUashnDP4n7ir7LbNdRfXpkMU7R', subnet_name='any-any', symbol='φ', tempo=360, last_step=5055782, blocks_since_last_step=191, emission=τ0.000000000, alpha_in=‎97,562.446308159φ‎, alpha_out=‎120,529.541355092φ‎, tao_in=τ523.130873034, price=τ0.005362010, k=51037927712519967867284406, is_dynamic=True, alpha_out_emission=‎1.000000000φ‎, alpha_in_emission=‎0.722895467φ‎, tao_in_emission=τ0.003876200, pending_alpha_emission=‎91.494649358φ‎, pending_root_emission=τ0.349440787, network_registered_at=3156578, subnet_volume=‎2,741.339153189φ‎, subnet_identity=None, moving_price=1.2654751378737839e-12)
# DynamicInfo(netuid=22, owner_hotkey='5HZ3rviPkBERT9H5dE5km4hML1PCyjLo5yX8B3Y4fvamBwxw', owner_coldkey='5HZ3rviPkBERT9H5dE5km4hML1PCyjLo5yX8B3Y4fvamBwxw', subnet_name='meta', symbol='χ', tempo=360, last_step=5055781, blocks_since_last_step=192, emission=τ0.000000000, alpha_in=‎97,814.722252508χ‎, alpha_out=‎123,126.533937847χ‎, tao_in=τ440.404029988, price=τ0.004502430, k=43077997872161424140209904, is_dynamic=True, alpha_out_emission=‎1.000000000χ‎, alpha_in_emission=‎0.722687340χ‎, tao_in_emission=τ0.003253872, pending_alpha_emission=‎92.117414960χ‎, pending_root_emission=τ0.294310931, network_registered_at=2009702, subnet_volume=‎1,639.140674599χ‎, subnet_identity=None, moving_price=1.0623019933327094e-12)
# DynamicInfo(netuid=23, owner_hotkey='5HN1QZq7MyGnutpToCZGdiabP3D339kBjKXfjb1YFaHacdta', owner_coldkey='5GvTa4JUKbUHqeJH8YLUDaV7jHChrfUy4n5zWrcCiU7bySoc', subnet_name='social', symbol='ψ', tempo=360, last_step=5055780, blocks_since_last_step=193, emission=τ0.000000000, alpha_in=‎115,832.562990244ψ‎, alpha_out=‎96,424.626535030ψ‎, tao_in=τ272.792415702, price=τ0.002355058, k=31598244675062741418411288, is_dynamic=True, alpha_out_emission=‎1.000000000ψ‎, alpha_in_emission=‎0.769383373ψ‎, tao_in_emission=τ0.001811953, pending_alpha_emission=‎92.156473121ψ‎, pending_root_emission=τ0.155659051, network_registered_at=2063528, subnet_volume=‎1,997.491710861ψ‎, subnet_identity=SubnetIdentity(subnet_name='Zuvu', github_repo='https://github.com/SocialTensor/SocialTensorSubnet', subnet_contact='', subnet_url='', discord='', description='', additional=''), moving_price=5.915434158135224e-13)
# DynamicInfo(netuid=24, owner_hotkey='5FpX2DN3A38JzXfEDZwBsDhCM527L6BDPi6MKGeXvGxFPipx', owner_coldkey='5FpX2DN3A38JzXfEDZwBsDhCM527L6BDPi6MKGeXvGxFPipx', subnet_name='omega', symbol='ω', tempo=360, last_step=5055779, blocks_since_last_step=194, emission=τ0.000000000, alpha_in=‎126,042.045905068ω‎, alpha_out=‎98,793.408656818ω‎, tao_in=τ508.111136658, price=τ0.004031282, k=64043367211523915842782744, is_dynamic=True, alpha_out_emission=‎1.000000000ω‎, alpha_in_emission=‎0.851035869ω‎, tao_in_emission=τ0.003431327, pending_alpha_emission=‎93.273758482ω‎, pending_root_emission=τ0.264780298, network_registered_at=2538424, subnet_volume=‎3,491.376897380ω‎, subnet_identity=None, moving_price=1.1201861378588862e-12)
# DynamicInfo(netuid=25, owner_hotkey='5F6aRdsBHajN2NhZHBTB6ibBFu7YuZZEWruWzB8x6B6GiZ4D', owner_coldkey='5F6aRdsBHajN2NhZHBTB6ibBFu7YuZZEWruWzB8x6B6GiZ4D', subnet_name='protein', symbol='א', tempo=360, last_step=5055778, blocks_since_last_step=195, emission=τ0.000000000, alpha_in=‎60,660.795658500א‎, alpha_out=‎162,910.239241416א‎, tao_in=τ1,313.186893854, price=τ0.021648032, k=79658961829497823532859000, is_dynamic=True, alpha_out_emission=‎1.000000000א‎, alpha_in_emission=‎0.553676031א‎, tao_in_emission=τ0.011986130, pending_alpha_emission=‎93.691618016א‎, pending_root_emission=τ1.400665998, network_registered_at=2998801, subnet_volume=‎13,202.075147140א‎, subnet_identity=SubnetIdentity(subnet_name='Folding', github_repo='https://github.com/macrocosm-os/folding', subnet_contact='support@macrocosmos.ai', subnet_url='https://www.macrocosmos.ai/sn25', discord='macrocrux', description='Protein folding and drug discovery', additional=''), moving_price=3.913503635738502e-12)
# DynamicInfo(netuid=26, owner_hotkey='5FnLxqpzUFgrzW8aLjR5oYB8BUUS7XN9efw3N3diPpaxmTgt', owner_coldkey='5GsfAD4a3KXYKx2TF9UcajcW6C85Bw5vZsCTmrFep7RgMjcm', subnet_name='alchemy', symbol='ב', tempo=360, last_step=5055777, blocks_since_last_step=196, emission=τ0.000000000, alpha_in=‎119,792.365569753ב‎, alpha_out=‎111,264.041589299ב‎, tao_in=τ246.010630487, price=τ0.002053641, k=29470195381344126506859711, is_dynamic=True, alpha_out_emission=‎1.000000000ב‎, alpha_in_emission=‎0.701763926ב‎, tao_in_emission=τ0.001441179, pending_alpha_emission=‎94.552346457ב‎, pending_root_emission=τ0.135958074, network_registered_at=4893280, subnet_volume=‎1,223.027870991ב‎, subnet_identity=None, moving_price=4.705106746924481e-13)
# DynamicInfo(netuid=27, owner_hotkey='5Cyfk5Jjee6uCafjZyUUjtKd7Q4qh1yJ48Ts7bkT9xXaDqe1', owner_coldkey='5Cyfk5Jjee6uCafjZyUUjtKd7Q4qh1yJ48Ts7bkT9xXaDqe1', subnet_name='compute', symbol='ג', tempo=360, last_step=5055776, blocks_since_last_step=197, emission=τ0.000000000, alpha_in=‎116,946.251102795ג‎, alpha_out=‎108,494.930929988ג‎, tao_in=τ742.525483013, price=τ0.006349288, k=86835571586662441289321335, is_dynamic=True, alpha_out_emission=‎1.000000000ג‎, alpha_in_emission=‎0.730278332ג‎, tao_in_emission=τ0.004636774, pending_alpha_emission=‎94.747681960ג‎, pending_root_emission=τ0.424148071, network_registered_at=1727132, subnet_volume=‎9,382.712486943ג‎, subnet_identity=SubnetIdentity(subnet_name='NI Compute', github_repo='https://github.com/neuralinternet/compute-subnet', subnet_contact='neuralinternet@gmail.com', subnet_url='https://neuralinternet.ai/', discord='https://discord.com/invite/neuralinternet', description='Transforming AI compute power into a digital commodity', additional='$NI'), moving_price=1.5137777099535898e-12)
# DynamicInfo(netuid=28, owner_hotkey='5Ca8L8PkbqXUtzohKtSM3i1naGQxANGLx51kJsEPNB14Admz', owner_coldkey='5Ca8L8PkbqXUtzohKtSM3i1naGQxANGLx51kJsEPNB14Admz', subnet_name='oracle', symbol='ד', tempo=360, last_step=5055775, blocks_since_last_step=198, emission=τ0.000000000, alpha_in=‎181,384.054530861ד‎, alpha_out=‎40,431.879153367ד‎, tao_in=τ347.100064665, price=τ0.001913619, k=62958417056861739338126565, is_dynamic=True, alpha_out_emission=‎1.000000000ד‎, alpha_in_emission=‎0.857664127ד‎, tao_in_emission=τ0.001603639, pending_alpha_emission=‎95.040503547ד‎, pending_root_emission=τ0.127750490, network_registered_at=4878363, subnet_volume=‎323,201.812324976ד‎, subnet_identity=None, moving_price=5.235207341421078e-13)
# DynamicInfo(netuid=29, owner_hotkey='5HHHHHzgLnYRvnKkHd45cRUDMHXTSwx7MjUzxBrKbY4JfZWn', owner_coldkey='5HHHHHzgLnYRvnKkHd45cRUDMHXTSwx7MjUzxBrKbY4JfZWn', subnet_name='coldint', symbol='ה', tempo=360, last_step=5055774, blocks_since_last_step=199, emission=τ0.000000000, alpha_in=‎120,045.746950443ה‎, alpha_out=‎121,900.620570474ה‎, tao_in=τ1,374.815508247, price=τ0.011452429, k=165040754606564043366803421, is_dynamic=True, alpha_out_emission=‎1.000000000ה‎, alpha_in_emission=‎0.714623864ה‎, tao_in_emission=τ0.008184225, pending_alpha_emission=‎96.554314087ה‎, pending_root_emission=τ0.763468607, network_registered_at=3379782, subnet_volume=‎22,922.768861146ה‎, subnet_identity=None, moving_price=2.6719387878453016e-12)
# DynamicInfo(netuid=30, owner_hotkey='5DcErZoVeG7ZShXwKFgJURuGXmdAVwmYzyvLAgpPjrPznDMB', owner_coldkey='5DcErZoVeG7ZShXwKFgJURuGXmdAVwmYzyvLAgpPjrPznDMB', subnet_name='bet', symbol='ו', tempo=360, last_step=5055773, blocks_since_last_step=200, emission=τ0.000000000, alpha_in=‎139,423.467994809ו‎, alpha_out=‎98,486.690422546ו‎, tao_in=τ1,435.107584054, price=τ0.010293156, k=200087676314460535803175686, is_dynamic=True, alpha_out_emission=‎1.000000000ו‎, alpha_in_emission=‎0.732929642ו‎, tao_in_emission=τ0.007544195, pending_alpha_emission=‎96.833716600ו‎, pending_root_emission=τ0.691717841, network_registered_at=3250216, subnet_volume=‎12,872.268194224ו‎, subnet_identity=None, moving_price=2.4629671674554487e-12)
ha_out=‎121,055.622788644י‎, tao_in=τ9,257.863340893, price=τ0.101148296, k=847350239597061028507078418, is_dynamic=True, alpha_out_emission=‎1.000000000י‎, alpha_in_emission=‎0.690720692י‎, tao_in_emission=τ0.069865744, pending_alpha_emission=‎97.424215989י‎, pending_root_emission=τ7.076555258, network_registered_at=3493948, subnet_volume=‎75,722.380528359י‎, subnet_identity=None, moving_price=2.2809602785115596e-11)
# DynamicInfo(netuid=35, owner_hotkey='5EsmkLf4VnpgNM31syMjAWsUrQdW2Yu5xzWbv6oDQydP9vVx', owner_coldkey='5EsmkLf4VnpgNM31syMjAWsUrQdW2Yu5xzWbv6oDQydP9vVx', subnet_name='logic', symbol='ך', tempo=360, last_step=5055768, blocks_since_last_step=205, emission=τ0.000000000, alpha_in=‎149,790.129134894ך‎, alpha_out=‎87,004.165618105ך‎, tao_in=τ772.561002202, price=τ0.005157622, k=115722012284420707889036588, is_dynamic=True, alpha_out_emission=‎1.000000000ך‎, alpha_in_emission=‎0.737269894ך‎, tao_in_emission=τ0.003802577, pending_alpha_emission=‎99.195764065ך‎, pending_root_emission=τ0.357927365, network_registered_at=3037158, subnet_volume=‎5,141.603531025ך‎, subnet_identity=None, moving_price=1.2414320331270712e-12)
# DynamicInfo(netuid=36, owner_hotkey='5DPtMdkMau8G8fGbPxdYSKCBo94oC7mDyHKMvVdNdsLVT3EF', owner_coldkey='5DPtMdkMau8G8fGbPxdYSKCBo94oC7mDyHKMvVdNdsLVT3EF', subnet_name='automata', symbol='כ', tempo=360, last_step=5055767, blocks_since_last_step=206, emission=τ0.000000000, alpha_in=‎101,474.588123732כ‎, alpha_out=‎109,310.027521908כ‎, tao_in=τ262.688664224, price=τ0.002588713, k=26656224006903733513763968, is_dynamic=True, alpha_out_emission=‎1.000000000כ‎, alpha_in_emission=‎0.747869317כ‎, tao_in_emission=τ0.001936032, pending_alpha_emission=‎98.280358538כ‎, pending_root_emission=τ0.184880185, network_registered_at=4871163, subnet_volume=‎1,553.192645030כ‎, subnet_identity=SubnetIdentity(subnet_name='web-agents', github_repo='https://github.com/autoppia/autoppia_web_agents_subnet', subnet_contact='', subnet_url='autoppia.com', discord='', description='', additional=''), moving_price=6.320563647119193e-13)
# DynamicInfo(netuid=37, owner_hotkey='5DXqqdrvu5FK3dASRVTCdGPZKx4Q9nkAZZSmibKG6PEEeW4j', owner_coldkey='5DXqqdrvu5FK3dASRVTCdGPZKx4Q9nkAZZSmibKG6PEEeW4j', subnet_name='tuning', symbol='ל', tempo=360, last_step=5055766, blocks_since_last_step=207, emission=τ0.000000000, alpha_in=‎67,579.017939340ל‎, alpha_out=‎151,075.603491765ל‎, tao_in=τ516.037654937, price=τ0.007636063, k=34873317940362467717521580, is_dynamic=True, alpha_out_emission=‎1.000000000ל‎, alpha_in_emission=‎0.627362371ל‎, tao_in_emission=τ0.004790626, pending_alpha_emission=‎99.189480551ל‎, pending_root_emission=τ0.547960757, network_registered_at=3212175, subnet_volume=‎4,972.856704846ל‎, subnet_identity=SubnetIdentity(subnet_name='Finetuning', github_repo='https://github.com/macrocosm-os/finetuning', subnet_contact='support@macrocosmos.ai', subnet_url='https://www.macrocosmos.ai/sn37', discord='macrocrux', description='SOTA models built by Bittensor', additional=''), moving_price=1.5640813839402912e-12)
# DynamicInfo(netuid=38, owner_hotkey='5EFJ7mEVyjxT3iXqxuHyMMuGgJKFt85tb5s4vEvnCTpSoP3w', owner_coldkey='5EFJ7mEVyjxT3iXqxuHyMMuGgJKFt85tb5s4vEvnCTpSoP3w', subnet_name='distributed', symbol='ם', tempo=360, last_step=5055765, blocks_since_last_step=208, emission=τ0.000000000, alpha_in=‎107,525.160024887ם‎, alpha_out=‎120,733.278083412ם‎, tao_in=τ259.271833441, price=τ0.002411266, k=27878245380689373678846167, is_dynamic=True, alpha_out_emission=‎1.000000000ם‎, alpha_in_emission=‎0.731669461ם‎, tao_in_emission=τ0.001764261, pending_alpha_emission=‎100.189823824ם‎, pending_root_emission=τ0.169794623, network_registered_at=3756684, subnet_volume=‎1,470.638581158ם‎, subnet_identity=None, moving_price=5.759817536116207e-13)
# DynamicInfo(netuid=39, owner_hotkey='5G3qVaXzKMPDm5AJ3dpzbpUC27kpccBvDwzSWXrq8M6qMmbC', owner_coldkey='5G3qVaXzKMPDm5AJ3dpzbpUC27kpccBvDwzSWXrq8M6qMmbC', subnet_name='edge', symbol='מ', tempo=360, last_step=5055764, blocks_since_last_step=209, emission=τ0.000000000, alpha_in=‎104,477.420873601מ‎, alpha_out=‎118,257.965190644מ‎, tao_in=τ261.199856423, price=τ0.002500060, k=27289487331629924430989223, is_dynamic=True, alpha_out_emission=‎1.000000000מ‎, alpha_in_emission=‎0.714079471מ‎, tao_in_emission=τ0.001785253, pending_alpha_emission=‎100.370926315מ‎, pending_root_emission=τ0.177540248, network_registered_at=3280104, subnet_volume=‎2,082.341112675מ‎, subnet_identity=None, moving_price=5.828393323525916e-13)
# DynamicInfo(netuid=40, owner_hotkey='5F9Qvcz22Fwq4cm58o2bShiL6n8BnJmhqXB1cispBpqRfN6w', owner_coldkey='5F9Qvcz22Fwq4cm58o2bShiL6n8BnJmhqXB1cispBpqRfN6w', subnet_name='chunk', symbol='ן', tempo=360, last_step=5055763, blocks_since_last_step=210, emission=τ0.000000000, alpha_in=‎99,725.509957993ן‎, alpha_out=‎121,225.197414934ן‎, tao_in=τ793.163179361, price=τ0.007953463, k=79098602541678793434582473, is_dynamic=True, alpha_out_emission=‎1.000000000ן‎, alpha_in_emission=‎0.731792584ן‎, tao_in_emission=τ0.005820325, pending_alpha_emission=‎100.752855515ן‎, pending_root_emission=τ0.568667407, network_registered_at=3372582, subnet_volume=‎4,471.152768028ן‎, subnet_identity=None, moving_price=1.9001728359183123e-12)
# DynamicInfo(netuid=41, owner_hotkey='5FCSevLkofmKZRixMawp6jyyjBty1AeSCLa7N5Fv892DYkXX', owner_coldkey='5FCSevLkofmKZRixMawp6jyyjBty1AeSCLa7N5Fv892DYkXX', subnet_name='sportsensor', symbol='נ', tempo=360, last_step=5055762, blocks_since_last_step=211, emission=τ0.000000000, alpha_in=‎84,041.441320917נ‎, alpha_out=‎138,665.844863251נ‎, tao_in=τ1,333.608860693, price=τ0.015868467, k=112078410810985733360015481, is_dynamic=True, alpha_out_emission=‎1.000000000נ‎, alpha_in_emission=‎0.670143568נ‎, tao_in_emission=τ0.010634237, pending_alpha_emission=‎101.330011880נ‎, pending_root_emission=τ1.138625162, network_registered_at=3394182, subnet_volume=‎21,868.667882766נ‎, subnet_identity=SubnetIdentity(subnet_name='SPORTSTENSOR', github_repo='https://github.com/sportstensor/sportstensor', subnet_contact='sportstensor@gmail.com', subnet_url='https://www.sportstensor.com/', discord='', description='Incentivized sports predictions beating the market.', additional=''), moving_price=3.471873504835854e-12)
# DynamicInfo(netuid=42, owner_hotkey='5Gbdb5s2WrRaFXTgMUiVNBKACe3cgSLwZNyK2Vwvjfvf6jUJ', owner_coldkey='5Gbdb5s2WrRaFXTgMUiVNBKACe3cgSLwZNyK2Vwvjfvf6jUJ', subnet_name='masa', symbol='ס', tempo=360, last_step=5055761, blocks_since_last_step=212, emission=τ0.000000000, alpha_in=‎108,182.056210918ס‎, alpha_out=‎107,604.131563876ס‎, tao_in=τ2,159.371924956, price=τ0.019960536, k=233605294965868197203869608, is_dynamic=True, alpha_out_emission=‎1.000000000ס‎, alpha_in_emission=‎0.679270415ס‎, tao_in_emission=τ0.013558688, pending_alpha_emission=‎101.424328877ס‎, pending_root_emission=τ1.451311276, network_registered_at=3613591, subnet_volume=‎20,213.967379730ס‎, subnet_identity=None, moving_price=4.4266314246955984e-12)
# DynamicInfo(netuid=43, owner_hotkey='5HjMs5JDrLH3Hknmfm1gDq7nFYAv6M7t9v3EWMctSRXJS9HC', owner_coldkey='5HjMs5JDrLH3Hknmfm1gDq7nFYAv6M7t9v3EWMctSRXJS9HC', subnet_name='graphite', symbol='ע', tempo=360, last_step=5055760, blocks_since_last_step=213, emission=τ0.000000000, alpha_in=‎98,660.464753770ע‎, alpha_out=‎132,729.829532564ע‎, tao_in=τ795.123225487, price=τ0.008059187, k=78447226963064079643335990, is_dynamic=True, alpha_out_emission=‎1.000000000ע‎, alpha_in_emission=‎0.457361080ע‎, tao_in_emission=τ0.003685984, pending_alpha_emission=‎102.772172041ע‎, pending_root_emission=τ0.580127294, network_registered_at=3408582, subnet_volume=‎4,662.325243638ע‎, subnet_identity=None, moving_price=1.2035815052935384e-12)
# DynamicInfo(netuid=44, owner_hotkey='5FsREvyUXSZWYRqVyQLDdpYmZZPnkhZyW6HjooozKP1nQkwu', owner_coldkey='5FsREvyUXSZWYRqVyQLDdpYmZZPnkhZyW6HjooozKP1nQkwu', subnet_name='score', symbol='ף', tempo=360, last_step=5055759, blocks_since_last_step=214, emission=τ0.000000000, alpha_in=‎102,669.743328004ף‎, alpha_out=‎124,319.843473780ף‎, tao_in=τ973.963226090, price=τ0.009486370, k=99996554433575028880424360, is_dynamic=True, alpha_out_emission=‎1.000000000ף‎, alpha_in_emission=‎0.673190402ף‎, tao_in_emission=τ0.006386175, pending_alpha_emission=‎103.009437464ף‎, pending_root_emission=τ0.689480533, network_registered_at=3550319, subnet_volume=‎8,679.016638034ף‎, subnet_identity=None, moving_price=2.0849602426487035e-12)
# DynamicInfo(netuid=45, owner_hotkey='5Hmiaz4bLLbLw4LgTksJvJYPYp1XJ1GYkUfRiv4HGXX674DD', owner_coldkey='5FbcZiAHA75i2bPVrF7wa9mFaxV1eM27HR63kJtbpb8spvmf', subnet_name='gen42', symbol='פ', tempo=360, last_step=5055758, blocks_since_last_step=215, emission=τ0.000000000, alpha_in=‎112,877.514604714פ‎, alpha_out=‎111,677.791742186פ‎, tao_in=τ1,463.204914388, price=τ0.012962766, k=165162934093520768031225032, is_dynamic=True, alpha_out_emission=‎1.000000000פ‎, alpha_in_emission=‎0.786659222פ‎, tao_in_emission=τ0.010197341, pending_alpha_emission=‎103.353791669פ‎, pending_root_emission=τ0.946096553, network_registered_at=3633154, subnet_volume=‎15,278.858723361פ‎, subnet_identity=None, moving_price=3.3290780613974558e-12)
# DynamicInfo(netuid=46, owner_hotkey='5Ek83SLwZi1P6s3E3kCfmxZJ5HHVepDsdpxJERfvpiopG5jz', owner_coldkey='5Ek83SLwZi1P6s3E3kCfmxZJ5HHVepDsdpxJERfvpiopG5jz', subnet_name='neural', symbol='ץ', tempo=360, last_step=5055757, blocks_since_last_step=216, emission=τ0.000000000, alpha_in=‎111,637.076538063ץ‎, alpha_out=‎108,475.722058980ץ‎, tao_in=τ1,247.664500580, price=τ0.011176076, k=139285617345073608255576540, is_dynamic=True, alpha_out_emission=‎1.000000000ץ‎, alpha_in_emission=‎0.734868984ץ‎, tao_in_emission=τ0.008213001, pending_alpha_emission=‎103.583640623ץ‎, pending_root_emission=τ0.823268473, network_registered_at=3919107, subnet_volume=‎14,317.475363577ץ‎, subnet_identity=SubnetIdentity(subnet_name='Neural3D', github_repo='https://github.com/goneuralai/neural-subnet', subnet_contact='support@goneural.ai', subnet_url='https://goneural.ai/', discord='@neutanent', description='Neural3D is generating 3D assets for gaming and virtual exp.', additional=''), moving_price=2.6813114987860043e-12)
# DynamicInfo(netuid=47, owner_hotkey='5CS2niAKFcmvE3i2Lb9ukR66Enkn26ygievde3dMepJ9ha9x', owner_coldkey='5CS2niAKFcmvE3i2Lb9ukR66Enkn26ygievde3dMepJ9ha9x', subnet_name='condense', symbol='צ', tempo=360, last_step=5055756, blocks_since_last_step=217, emission=τ0.000000000, alpha_in=‎113,518.065331425צ‎, alpha_out=‎107,962.226455688צ‎, tao_in=τ431.532674265, price=τ0.003801444, k=48986754309858813793277625, is_dynamic=True, alpha_out_emission=‎1.000000000צ‎, alpha_in_emission=‎0.680133766צ‎, tao_in_emission=τ0.002585506, pending_alpha_emission=‎104.142002800צ‎, pending_root_emission=τ0.280605533, network_registered_at=4236387, subnet_volume=‎1,985.880884990צ‎, subnet_identity=SubnetIdentity(subnet_name='condenses.ai', github_repo='https://github.com/condenses/neural-condense-subnet', subnet_contact='', subnet_url='', discord='', description='Accelerating LLM inference by text-to-text compression.', additional=''), moving_price=8.441140581655349e-13)
# DynamicInfo(netuid=48, owner_hotkey='5D2Qc9ud7vTJrPzk8mT1ruY8oV8UaDP3ttepD7zVNNi943ch', owner_coldkey='5D2Qc9ud7vTJrPzk8mT1ruY8oV8UaDP3ttepD7zVNNi943ch', subnet_name='nextplace', symbol='ק', tempo=360, last_step=5055755, blocks_since_last_step=218, emission=τ0.000000000, alpha_in=‎129,629.527842858ק‎, alpha_out=‎86,242.574705940ק‎, tao_in=τ1,300.618807557, price=τ0.010033352, k=168598601927154902438877906, is_dynamic=True, alpha_out_emission=‎1.000000000ק‎, alpha_in_emission=‎0.718534684ק‎, tao_in_emission=τ0.007209669, pending_alpha_emission=‎104.304856791ק‎, pending_root_emission=τ0.746369344, network_registered_at=3856677, subnet_volume=‎21,546.526708054ק‎, subnet_identity=None, moving_price=2.3537675172650985e-12)
# DynamicInfo(netuid=49, owner_hotkey='5C6z6jXv1iuwKMwfuWrZgPrrtxQZh7YKYThLXoMA2VgFG8w2', owner_coldkey='5C6z6jXv1iuwKMwfuWrZgPrrtxQZh7YKYThLXoMA2VgFG8w2', subnet_name='automl', symbol='ר', tempo=360, last_step=5055754, blocks_since_last_step=219, emission=τ0.000000000, alpha_in=‎127,473.516791458ר‎, alpha_out=‎104,925.418153642ר‎, tao_in=τ197.895377906, price=τ0.001552443, k=25226419778452417502726948, is_dynamic=True, alpha_out_emission=‎1.000000000ר‎, alpha_in_emission=‎0.732612213ר‎, tao_in_emission=τ0.001137344, pending_alpha_emission=‎105.722078985ר‎, pending_root_emission=τ0.114728170, network_registered_at=4107524, subnet_volume=‎1,035.626744932ר‎, subnet_identity=None, moving_price=3.71311000609692e-13)
# DynamicInfo(netuid=50, owner_hotkey='5DxyiWpGqN5xXiczXcEGph51BcgTqcYKD5GKZqoACuc2sJkD', owner_coldkey='5DxyiWpGqN5xXiczXcEGph51BcgTqcYKD5GKZqoACuc2sJkD', subnet_name='audio', symbol='ש', tempo=360, last_step=5055753, blocks_since_last_step=220, emission=τ0.000000000, alpha_in=‎131,403.617748512ש‎, alpha_out=‎96,461.480750194ש‎, tao_in=τ898.640276685, price=τ0.006838778, k=118084583410932800427042720, is_dynamic=True, alpha_out_emission=‎1.000000000ש‎, alpha_in_emission=‎0.740749708ש‎, tao_in_emission=τ0.005065849, pending_alpha_emission=‎105.946786853ש‎, pending_root_emission=τ0.509464614, network_registered_at=4763204, subnet_volume=‎3,365.703413834ש‎, subnet_identity=SubnetIdentity(subnet_name='Synth', github_repo='https://github.com/mode-network/synth-subnet', subnet_contact='', subnet_url='', discord='', description='', additional=''), moving_price=1.653851860149158e-12)
# DynamicInfo(netuid=51, owner_hotkey='5FqACMtcegZxxopgu1g7TgyrnyD8skurr9QDPLPhxNQzsThe', owner_coldkey='5FqACMtcegZxxopgu1g7TgyrnyD8skurr9QDPLPhxNQzsThe', subnet_name='celium', symbol='ת', tempo=360, last_step=5055752, blocks_since_last_step=221, emission=τ0.000000000, alpha_in=‎100,322.031692424ת‎, alpha_out=‎129,699.795627214ת‎, tao_in=τ8,379.119597353, price=τ0.083522227, k=840610301800258692020553672, is_dynamic=True, alpha_out_emission=‎1.000000000ת‎, alpha_in_emission=‎0.676106259ת‎, tao_in_emission=τ0.056470281, pending_alpha_emission=‎106.552182381ת‎, pending_root_emission=τ6.206024943, network_registered_at=3966206, subnet_volume=‎66,167.724657527ת‎, subnet_identity=None, moving_price=1.8436407186062792e-11)
# DynamicInfo(netuid=52, owner_hotkey='5EgfUiH6A99dhihMzp7eMM8UDkvmFjCWgM5gnpBN8UgLrVuz', owner_coldkey='5EgfUiH6A99dhihMzp7eMM8UDkvmFjCWgM5gnpBN8UgLrVuz', subnet_name='dojo', symbol='ا', tempo=360, last_step=5055751, blocks_since_last_step=222, emission=τ0.000000000, alpha_in=‎94,853.223506660ا‎, alpha_out=‎117,298.784404983ا‎, tao_in=τ941.628813169, price=τ0.009927219, k=89316528275830148167205540, is_dynamic=True, alpha_out_emission=‎1.000000000ا‎, alpha_in_emission=‎0.748410193ا‎, tao_in_emission=τ0.007429686, pending_alpha_emission=‎105.993545530ا‎, pending_root_emission=τ0.755361226, network_registered_at=3989825, subnet_volume=‎8,438.420897465ا‎, subnet_identity=None, moving_price=2.425568372457082e-12)
# DynamicInfo(netuid=53, owner_hotkey='5F2HTUqtk9VWQwXkkUX9oFSXUkAib74qw7s3W7KyZP88AmYe', owner_coldkey='5F2HTUqtk9VWQwXkkUX9oFSXUkAib74qw7s3W7KyZP88AmYe', subnet_name='frontier', symbol='ب', tempo=360, last_step=5055750, blocks_since_last_step=223, emission=τ0.000000000, alpha_in=‎119,526.072152904ب‎, alpha_out=‎112,240.209457478ب‎, tao_in=τ2,044.954761433, price=τ0.017108859, k=244425410364465344018151432, is_dynamic=True, alpha_out_emission=‎1.000000000ب‎, alpha_in_emission=‎0.724766952ب‎, tao_in_emission=τ0.012400005, pending_alpha_emission=‎107.616514940ب‎, pending_root_emission=τ1.291456373, network_registered_at=4203869, subnet_volume=‎38,691.172332713ب‎, subnet_identity=None, moving_price=4.048265574759652e-12)
# DynamicInfo(netuid=54, owner_hotkey='5GENieJS4p6oKVPbDoXhAo46E38hxR7MxvbgMpJE4bf6xCb3', owner_coldkey='5GENieJS4p6oKVPbDoXhAo46E38hxR7MxvbgMpJE4bf6xCb3', subnet_name='safescan', symbol='ت', tempo=360, last_step=5055749, blocks_since_last_step=224, emission=τ0.000000000, alpha_in=‎104,461.962531655ت‎, alpha_out=‎118,374.453302086ت‎, tao_in=τ165.292636545, price=τ0.001582323, k=17266793205522257972331975, is_dynamic=True, alpha_out_emission=‎1.000000000ت‎, alpha_in_emission=‎0.729028416ت‎, tao_in_emission=τ0.001153566, pending_alpha_emission=‎107.579500380ت‎, pending_root_emission=τ0.120504964, network_registered_at=4742549, subnet_volume=‎1,338.519582075ت‎, subnet_identity=None, moving_price=3.7660738243239233e-13)
# DynamicInfo(netuid=55, owner_hotkey='5HmHiVeddZPNqjUJLccRiq5AVMTVaNYif5EQNrE5fumcf46r', owner_coldkey='5HmHiVeddZPNqjUJLccRiq5AVMTVaNYif5EQNrE5fumcf46r', subnet_name='unknown', symbol='ث', tempo=360, last_step=5055748, blocks_since_last_step=225, emission=τ0.000000000, alpha_in=‎111,451.220104349ث‎, alpha_out=‎93,733.467655030ث‎, tao_in=τ343.017555853, price=τ0.003077737, k=38229725117028529595704697, is_dynamic=True, alpha_out_emission=‎1.000000000ث‎, alpha_in_emission=‎0.743568877ث‎, tao_in_emission=τ0.002289146, pending_alpha_emission=‎107.006704242ث‎, pending_root_emission=τ0.239028598, network_registered_at=4703386, subnet_volume=‎2,231.608933002ث‎, subnet_identity=SubnetIdentity(subnet_name='precog', github_repo='https://github.com/coinmetrics/precog', subnet_contact='precog@coinmetrics.io', subnet_url='https://coinmetrics.io/precog/', discord='uriel_coinmetrics', description='', additional='Twitter: @CM_Precog'), moving_price=7.473386601404564e-13)
# DynamicInfo(netuid=56, owner_hotkey='5GU4Xkd3dCGTU3s8VLcHGc5wsD5M8XyxDca5yDQhYm1mVXFu', owner_coldkey='5G77DNXrfAxbvi53p3mh88kRMySBcJsv9j9cH4KU6ALWXgQF', subnet_name='gradients', symbol='ج', tempo=360, last_step=5055747, blocks_since_last_step=226, emission=τ0.000000000, alpha_in=‎65,538.108485956ج‎, alpha_out=‎154,333.710369217ج‎, tao_in=τ2,079.101360089, price=τ0.031723548, k=136260370490811552155410084, is_dynamic=True, alpha_out_emission=‎1.000000000ج‎, alpha_in_emission=‎0.596223105ج‎, tao_in_emission=τ0.018914508, pending_alpha_emission=‎108.365158442ج‎, pending_root_emission=τ2.393553610, network_registered_at=4312927, subnet_volume=‎23,662.416318223ج‎, subnet_identity=None, moving_price=6.175467201410129e-12)
# DynamicInfo(netuid=57, owner_hotkey='5GmhjCqDTsRcKqPFw4FDig8tVBfFGNrwP8ywe5En5hnELwDQ', owner_coldkey='5GmhjCqDTsRcKqPFw4FDig8tVBfFGNrwP8ywe5En5hnELwDQ', subnet_name='gaia', symbol='ح', tempo=360, last_step=5055746, blocks_since_last_step=227, emission=τ0.000000000, alpha_in=‎153,093.650934849ح‎, alpha_out=‎79,749.297624535ح‎, tao_in=τ514.005838962, price=τ0.003357460, k=78691030488522635847786738, is_dynamic=True, alpha_out_emission=‎1.000000000ح‎, alpha_in_emission=‎0.741113256ح‎, tao_in_emission=τ0.002488269, pending_alpha_emission=‎109.609494943ح‎, pending_root_emission=τ0.257097219, network_registered_at=4343091, subnet_volume=‎2,569.091277621ح‎, subnet_identity=None, moving_price=8.123470971420355e-13)
# DynamicInfo(netuid=58, owner_hotkey='5DyEYZ2pB3bP6BN8Xpo5ova3TEPiT82j5oHXqgQ8csKE9stH', owner_coldkey='5DyEYZ2pB3bP6BN8Xpo5ova3TEPiT82j5oHXqgQ8csKE9stH', subnet_name='dippy-speach', symbol='خ', tempo=360, last_step=5055745, blocks_since_last_step=228, emission=τ0.000000000, alpha_in=‎122,085.819490386خ‎, alpha_out=‎106,980.014695898خ‎, tao_in=τ743.245675579, price=τ0.006087895, k=90739757385747788065483494, is_dynamic=True, alpha_out_emission=‎1.000000000خ‎, alpha_in_emission=‎0.728886335خ‎, tao_in_emission=τ0.004437408, pending_alpha_emission=‎109.870072847خ‎, pending_root_emission=τ0.469531423, network_registered_at=4367003, subnet_volume=‎11,793.723721390خ‎, subnet_identity=None, moving_price=1.4486909393450487e-12)
# DynamicInfo(netuid=59, owner_hotkey='5FH9AQM4kqbkdC9jyV5FrdEWVYt41nkhFstop7Vhyfb9ZsXt', owner_coldkey='5FH9AQM4kqbkdC9jyV5FrdEWVYt41nkhFstop7Vhyfb9ZsXt', subnet_name='agent-arena', symbol='د', tempo=360, last_step=5055744, blocks_since_last_step=229, emission=τ0.000000000, alpha_in=‎116,301.143224482د‎, alpha_out=‎105,993.476400310د‎, tao_in=τ579.687724699, price=τ0.004984368, k=67418345095692490772880918, is_dynamic=True, alpha_out_emission=‎1.000000000د‎, alpha_in_emission=‎0.696637416د‎, tao_in_emission=τ0.003472317, pending_alpha_emission=‎109.948290805د‎, pending_root_emission=τ0.388068459, network_registered_at=4401833, subnet_volume=‎5,782.929230850د‎, subnet_identity=None, moving_price=1.1336310037392272e-12)
# DynamicInfo(netuid=60, owner_hotkey='5CXLwkK1Scd1uiMUrXYjJUTTPxqqyH2FTJQNLp9uXQhA9rhR', owner_coldkey='5CXLwkK1Scd1uiMUrXYjJUTTPxqqyH2FTJQNLp9uXQhA9rhR', subnet_name='unknown', symbol='ذ', tempo=360, last_step=5055743, blocks_since_last_step=230, emission=τ0.000000000, alpha_in=‎103,031.823007013ذ‎, alpha_out=‎107,124.349002962ذ‎, tao_in=τ404.143270061, price=τ0.003922509, k=41639617870400407955937793, is_dynamic=True, alpha_out_emission=‎1.000000000ذ‎, alpha_in_emission=‎0.797014017ذ‎, tao_in_emission=τ0.003126315, pending_alpha_emission=‎109.690051952ذ‎, pending_root_emission=τ0.309766397, network_registered_at=4796992, subnet_volume=‎2,281.844420562ذ‎, subnet_identity=None, moving_price=1.0206298696815996e-12)
# DynamicInfo(netuid=61, owner_hotkey='5ECEsYL82fbXx9KfTZy7G2KXSurnScciJyAVMHZjekc8jUbn', owner_coldkey='5ECEsYL82fbXx9KfTZy7G2KXSurnScciJyAVMHZjekc8jUbn', subnet_name='red team', symbol='ر', tempo=360, last_step=5055742, blocks_since_last_step=231, emission=τ0.000000000, alpha_in=‎105,068.745829092ر‎, alpha_out=‎124,634.276590108ر‎, tao_in=τ633.895218198, price=τ0.006033147, k=66602575563122475756216216, is_dynamic=True, alpha_out_emission=‎1.000000000ر‎, alpha_in_emission=‎0.667245283ر‎, tao_in_emission=τ0.004025614, pending_alpha_emission=‎111.353978195ر‎, pending_root_emission=τ0.471448458, network_registered_at=4457976, subnet_volume=‎8,912.318960675ر‎, subnet_identity=None, moving_price=1.3142874375621227e-12)
# DynamicInfo(netuid=62, owner_hotkey='5EsNzkZ3DwDqCsYmSJDeGXX51dQJd5broUCH6dbDjvkTcicD', owner_coldkey='5EsNzkZ3DwDqCsYmSJDeGXX51dQJd5broUCH6dbDjvkTcicD', subnet_name='agentao', symbol='ز', tempo=360, last_step=5055741, blocks_since_last_step=232, emission=τ0.000000000, alpha_in=‎124,522.359618629ز‎, alpha_out=‎96,941.526095572ز‎, tao_in=τ302.212365381, price=τ0.002426972, k=37632196843169387162282649, is_dynamic=True, alpha_out_emission=‎1.000000000ز‎, alpha_in_emission=‎0.746389033ز‎, tao_in_emission=τ0.001811475, pending_alpha_emission=‎111.337651249ز‎, pending_root_emission=τ0.192029525, network_registered_at=4474225, subnet_volume=‎1,722.670057981ز‎, subnet_identity=None, moving_price=5.913926032913297e-13)
# DynamicInfo(netuid=63, owner_hotkey='5GmpedVP2r9haksUBD743wek8t89jMz96RTkV2zkVdRR4e1B', owner_coldkey='5GmpedVP2r9haksUBD743wek8t89jMz96RTkV2zkVdRR4e1B', subnet_name='lean-in', symbol='س', tempo=360, last_step=5055740, blocks_since_last_step=233, emission=τ0.000000000, alpha_in=‎107,335.688398264س‎, alpha_out=‎112,382.500993603س‎, tao_in=τ152.557905141, price=τ0.001421315, k=16374907768906293541075224, is_dynamic=True, alpha_out_emission=‎1.000000000س‎, alpha_in_emission=‎0.712563453س‎, tao_in_emission=τ0.001012784, pending_alpha_emission=‎111.711036823س‎, pending_root_emission=τ0.113701552, network_registered_at=4885578, subnet_volume=‎1,296.608834587س‎, subnet_identity=None, moving_price=3.3064816076094905e-13)
# DynamicInfo(netuid=64, owner_hotkey='5F4Q3cA8EvApwhBj4eLjbb1meiLtzKgWhkF5JLRMNhRfqULc', owner_coldkey='5DyV8a62E2t2C4FoSqjihdV5USVXPEZYvZtUjXxZq1Mnvwwg', subnet_name='chutes', symbol='ش', tempo=360, last_step=5055739, blocks_since_last_step=234, emission=τ0.000000000, alpha_in=‎87,668.527677558ش‎, alpha_out=‎139,134.585227538ش‎, tao_in=τ17,551.465818110, price=τ0.200202584, k=1538711166856689700756975380, is_dynamic=True, alpha_out_emission=‎1.000000000ش‎, alpha_in_emission=‎0.717903896ش‎, tao_in_emission=τ0.143727325, pending_alpha_emission=‎112.623637076ش‎, pending_root_emission=τ15.973907313, network_registered_at=4531295, subnet_volume=‎133,889.812772476ش‎, subnet_identity=None, moving_price=4.6923206693891967e-11)
# DynamicInfo(netuid=65, owner_hotkey='5GHrTeuFnJYjNJx773URbYb9Pk3bRRDiJHJFBNECZpjGqZPY', owner_coldkey='5C8UAnEkWyuDTMysj3Hg3n2q787R6xvvcqvV5x4bujEWGRgE', subnet_name='sad', symbol='ص', tempo=360, last_step=5055738, blocks_since_last_step=235, emission=τ0.000000000, alpha_in=‎79,129.154973491ص‎, alpha_out=‎71,281.503048964ص‎, tao_in=τ299.257177101, price=τ0.003781882, k=23679967543754471147229591, is_dynamic=True, alpha_out_emission=‎1.000000000ص‎, alpha_in_emission=‎0.684892757ص‎, tao_in_emission=τ0.002590207, pending_alpha_emission=‎108.148523526ص‎, pending_root_emission=τ0.323062315, network_registered_at=4950813, subnet_volume=‎1,942.242107117ص‎, subnet_identity=SubnetIdentity(subnet_name='Tensor Private Network (TPN)', github_repo='', subnet_contact='', subnet_url='', discord='', description='', additional=''), moving_price=8.456469574071035e-13)
# DynamicInfo(netuid=66, owner_hotkey='5HTtLX9vd25V5cVNRroUnBocKn9Xn2xqmMEBZhTTerP4R5gg', owner_coldkey='5Grk5jAYsWSUMkAqKX5fmLyEKG8StdjbNPBXTPvz413MWik5', subnet_name='dad', symbol='ض', tempo=360, last_step=5055737, blocks_since_last_step=236, emission=τ0.000000000, alpha_in=‎88,457.983678643ض‎, alpha_out=‎49,458.895538753ض‎, tao_in=τ316.437037736, price=τ0.003577258, k=27991382319369227088272248, is_dynamic=True, alpha_out_emission=‎1.000000000ض‎, alpha_in_emission=‎0.772221813ض‎, tao_in_emission=τ0.002762459, pending_alpha_emission=‎107.734218094ض‎, pending_root_emission=τ0.308678124, network_registered_at=4958013, subnet_volume=‎6,180.758014753ض‎, subnet_identity=SubnetIdentity(subnet_name='FakeNews', github_repo='https://github.com/gutenberg-team/fakenews-subnet', subnet_contact='', subnet_url='https://taostats.io/subnets/66/chart', discord='', description='', additional=''), moving_price=9.018516727681003e-13)
# DynamicInfo(netuid=67, owner_hotkey='5EAKmsFz6Ytpkgy5nuHJ7WpxwJm7PV9MfcPkmpizkn37BWJp', owner_coldkey='5H9djFYLbh72qDkXq3283FfnhzL5np4TmQgir9kBQmg99GkG', subnet_name='ta', symbol='ط', tempo=360, last_step=5055736, blocks_since_last_step=237, emission=τ0.000000000, alpha_in=‎60,504.077715391ط‎, alpha_out=‎77,444.092260617ط‎, tao_in=τ156.082451716, price=τ0.002579701, k=9443624788633627347560956, is_dynamic=True, alpha_out_emission=‎1.000000000ط‎, alpha_in_emission=‎0.696442163ط‎, tao_in_emission=τ0.001796634, pending_alpha_emission=‎108.193506260ط‎, pending_root_emission=τ0.222803308, network_registered_at=4965213, subnet_volume=‎652.353602024ط‎, subnet_identity=None, moving_price=5.865593384266066e-13)
# DynamicInfo(netuid=68, owner_hotkey='5CSuegTfX4Gf7SoXXJoPEyMEicXBjm5Z1QgoPPcU424rQbbb', owner_coldkey='5EcdJLAeYoxM3Tsf5VZ3NQPenPku218gqnjSoo3iJNy4V12V', subnet_name='dha', symbol='ظ', tempo=360, last_step=5055735, blocks_since_last_step=238, emission=τ0.000000000, alpha_in=‎22,686.160669200ظ‎, alpha_out=‎94,363.927733338ظ‎, tao_in=τ702.943476363, price=τ0.030985563, k=15947088646137010462119600, is_dynamic=True, alpha_out_emission=‎1.000000000ظ‎, alpha_in_emission=‎0.660863366ظ‎, tao_in_emission=τ0.020477891, pending_alpha_emission=‎107.135350851ظ‎, pending_root_emission=τ2.726387214, network_registered_at=4972413, subnet_volume=‎4,081.180437682ظ‎, subnet_identity=SubnetIdentity(subnet_name='NOVA', github_repo='https://github.com/metanova-labs/nova/', subnet_contact='', subnet_url='https://www.metanova-labs.com/', discord='', description='Accelerating drug discovery', additional=''), moving_price=6.6856669939802105e-12)
# DynamicInfo(netuid=69, owner_hotkey='5DPbvQvifGf4JEgUfXwZz1htsVK7onAurspVfehhWSqZEDuA', owner_coldkey='5EsorPyFCP7TaNz3QrNvDvr8ZDVtG9hfzNEfGeAVG9wbFi2B', subnet_name='ain', symbol='ع', tempo=360, last_step=5055734, blocks_since_last_step=239, emission=τ0.000000000, alpha_in=‎56,834.611102901ع‎, alpha_out=‎57,965.638272136ع‎, tao_in=τ224.754506286, price=τ0.003954535, k=12773834958389328197335686, is_dynamic=True, alpha_out_emission=‎1.000000000ع‎, alpha_in_emission=‎0.667949599ع‎, tao_in_emission=τ0.002641464, pending_alpha_emission=‎107.418364197ع‎, pending_root_emission=τ0.347161024, network_registered_at=4979613, subnet_volume=‎3,165.144395446ع‎, subnet_identity=None, moving_price=8.62388285782778e-13)
# DynamicInfo(netuid=70, owner_hotkey='5GrypYms8VDs2otn6D4bH4tj3LyuXhWfcJHUJjdRGk1BXM96', owner_coldkey='5GayCfNEMcf3jLsVbXK9wMNsWpXg6axNSooPAeKuJfjJfkSz', subnet_name='ghayn', symbol='غ', tempo=360, last_step=5055733, blocks_since_last_step=240, emission=τ0.000000000, alpha_in=‎32,385.592899741غ‎, alpha_out=‎46,561.452581267غ‎, tao_in=τ549.255398863, price=τ0.016959868, k=17787961745561983724394483, is_dynamic=True, alpha_out_emission=‎1.000000000غ‎, alpha_in_emission=‎0.567319235غ‎, tao_in_emission=τ0.009621886, pending_alpha_emission=‎105.108900705غ‎, pending_root_emission=τ1.603020155, network_registered_at=5008428, subnet_volume=‎1,744.414064022غ‎, subnet_identity=None, moving_price=3.141542310580031e-12)
# DynamicInfo(netuid=71, owner_hotkey='5EM38qBzSMi8NLvmeXT6rLZN6MkWmR1Ju2vWmxjPXmw389aX', owner_coldkey='5G9yDFTi5DMYdbCz15H4m7r54b8gC8BGDmpqmsYxUbGKKwf6', subnet_name='fa', symbol='ف', tempo=360, last_step=5055732, blocks_since_last_step=241, emission=τ0.000000000, alpha_in=‎3,118.160901295ف‎, alpha_out=‎9,753.128376367ف‎, tao_in=τ23.673207004, price=τ0.007592041, k=73816868488135746670180, is_dynamic=True, alpha_out_emission=‎1.000000000ف‎, alpha_in_emission=‎0.919173241ف‎, tao_in_emission=τ0.000000000, pending_alpha_emission=‎99.957505795ف‎, pending_root_emission=τ0.778445314, network_registered_at=5048438, subnet_volume=‎170.458818548ف‎, subnet_identity=None, moving_price=2.279380406210868e-12)

# %% [markdown]
# ## 5. Get Neurons in the Subnet

# %%
# Get all neurons in the subnet
neurons = subtensor.neurons(netuid=NETUID)
print(f"Got {len(neurons)} neurons in subnet {NETUID}")


# Select a neuron UID for further exploration
# We'll use UID 0 by default
UID = 0  # Change this to explore different neurons

# Get detailed info for a specific neuron
neuron_info = subtensor.neuron_for_uid(netuid=NETUID, uid=UID)
print_result(neuron_info, f"Neuron {UID} Info")

# Extract hotkey for further queries
HOTKEY = neuron_info.hotkey
# Out:
# Got 256 neurons in subnet 30
#
# === Neuron 0 Info ===
#
# {
#   "hotkey": "5DdAdmAW4MCdSMDJhWPDvZKCbCAAbg8WDxvSMuqvv5nPVEjc",
#       229,
#       29557
#     ],
#     [
#       231,
#       29557
#     ],
#     [
#       232,
#       29557
#     ],
#     [
#       233,
#       29557
#     ],
#     [
#       234,
#       29557
#     ],
#     [
#       235,
#       48818
#     ],
#     [
#       236,
#       17565
#     ],
#     [
#       237,
#       13325
#     ],
#     [
#       238,
#       51968
#     ],
#     [
#       239,
#       40702
#     ],
#     [
#       241,
#       13325
#     ],
#     [
#       242,
#       29557
#     ],
#     [
#       244,
#       58872
#     ],
#     [
#       245,
#       40217
#     ],
#     [
#       246,
#       29557
#     ],
#     [
#       247,
#       29557
#     ],
#     [
#       248,
#       50029
#     ],
#     [
#       249,
#       29557
#     ],
#     [
#       251,
#       29557
#     ],
#     [
#       252,
#       29557
#     ],
#     [
#       253,
#       50756
#     ],
#     [
#       254,
#       29557
#     ],
#     [
#       255,
#       29557
#     ]
#   ],
#   "bonds": [],
#   "pruning_score": 15,
#   "prometheus_info": "PrometheusInfo(block=0, version=0, ip='0.0.0.0', port=0, ip_type=0)",
#   "axon_info": "AxonInfo( /ipv4/35.238.52.113:8014, 5DdAdmAW4MCdSMDJhWPDvZKCbCAAbg8WDxvSMuqvv5nPVEjc, 5EZYsL3oA7Yq92NcuMnPPnwYRATQrTUvC9ydGiQU8MGfRfFN, 9000000 )",
#   "is_null": false
# }

# %% [markdown]
# ## 6. Explore Stake Information Methods

# %%
# Get neuron stake by hotkey
neuron_stake = subtensor.get_neuron_stake_for_coldkey_and_hotkey(
    hotkey_ss58=HOTKEY,
    coldkey_ss58=neuron_info.coldkey  # If known, otherwise use neuron_info.coldkey from the previous cell
)
print(f"Stake for neuron {UID} with hotkey {HOTKEY}: {neuron_stake} τ")

# Get total stake for a hotkey
total_stake = subtensor.get_total_stake_for_hotkey(hotkey_ss58=HOTKEY)
print(f"Total stake for hotkey {HOTKEY} across all subnets: {total_stake} τ")

# Get total stake for a subnet
subnet_total_stake = subtensor.get_total_stake_for_subnet(netuid=NETUID)
print(f"Total stake in subnet {NETUID}: {subnet_total_stake} τ")

# For a validator, get the stake in a different way
if subtensor.is_hotkey_validator(hotkey_ss58=HOTKEY, netuid=NETUID):
    validator_stake = subtensor.get_stake_for_validator(netuid=NETUID, hotkey_ss58=HOTKEY)
    print(f"Validator stake for {HOTKEY}: {validator_stake} τ")

# %% [markdown]
# ## 7. Explore Ownership and Stake Distribution

# %%
# Get coldkey owner of the hotkey
coldkey_owner = subtensor.get_hotkey_owner(hotkey_ss58=HOTKEY)
print(f"Coldkey owner of hotkey {HOTKEY}: {coldkey_owner}")

# Get all stakes for this coldkey
if coldkey_owner:
    stakes = subtensor.get_stakes_for_coldkey(coldkey_ss58=coldkey_owner)
    print(f"\nFound {len(stakes)} stake entries for coldkey {coldkey_owner}:")
    
    # Convert to DataFrame for better visualization
    stake_data = []
    for s in stakes:
        stake_data.append({
            'hotkey': s.hotkey, 
            'stake': float(s.stake),
            'stake_in_tao': float(s.stake) / 1e9
        })
    
    if stake_data:
        df = pd.DataFrame(stake_data)
        display(df)
        
        # Create a pie chart of stake distribution
        plt.figure(figsize=(10, 6))
        plt.pie(df['stake_in_tao'], labels=df['hotkey'], autopct='%1.1f%%')
        plt.title(f"Stake Distribution for Coldkey {coldkey_owner}")
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Get coldkey owner of the hotkey
# ----> 2 coldkey_owner = subtensor.get_hotkey_owner(hotkey_ss58=HOTKEY)
#       3 print(f"Coldkey owner of hotkey {HOTKEY}: {coldkey_owner}")
#       5 # Get all stakes for this coldkey
#
# NameError: name 'HOTKEY' is not defined

# %% [markdown]
# ## 8. Detect Epoch Boundaries

# %%
# Detect epoch boundaries using subnet tempo and current block
def check_epoch_boundary(subtensor, netuid):
    """Check if we're at an epoch boundary by examining subnet state"""
    try:
        # Get subnet info to get the tempo
        subnet_info = subtensor.subnet(netuid)
        tempo = subnet_info.tempo
        
        # Get current block
        current_block = subtensor.get_current_block()
        
        # Calculate blocks until next epoch
        blocks_since_epoch_start = current_block % tempo
        blocks_until_next_epoch = tempo - blocks_since_epoch_start
        
        return {
            'current_block': current_block,
            'tempo': tempo,
            'blocks_since_epoch_start': blocks_since_epoch_start,
            'blocks_until_next_epoch': blocks_until_next_epoch,
            'is_epoch_boundary': blocks_since_epoch_start == 0
        }
            
    except Exception as e:
        print(f"Error checking epoch boundary: {e}")
        return None

epoch_check_result = check_epoch_boundary(subtensor, NETUID)
print_result(epoch_check_result, "Epoch Boundary Check")
# Out:
# === Epoch Boundary Check ===
#
# {
#   "current_block": 5056332,
#   "tempo": 360,
#   "blocks_since_epoch_start": 132,
#   "blocks_until_next_epoch": 228,
#   "is_epoch_boundary": false
# }

# %% [markdown]
# ## 9. Monitor Stake Changes Over Time

# %%
# Function to monitor stake changes over time
def monitor_stake_changes(subtensor, netuid,coldkey, interval_seconds=5, duration_minutes=1):
    """Monitor stake changes for a specific hotkey over time"""
    start_time = datetime.now(timezone.utc)
    end_time = start_time + timedelta(minutes=duration_minutes)
    
    stake_history = []
    
    print(f"Starting stake monitoring for hotkey {coldkey} in subnet {netuid}")
    print(f"Will run for {duration_minutes} minutes with {interval_seconds} second intervals")
    
    current_time = datetime.now(timezone.utc)
    while current_time < end_time:
        # Get current stake
        try:
            # Get current block
            current_block = subtensor.get_current_block()
            
            # Get stake
            stake_info= subtensor.get_stake_info_for_coldkey(coldkey)
            
            # Record timestamp and stake value
            stake_history.append({
                'timestamp': current_time,
                'block': current_block,
                'stake info': stake_info,
                
            })
            
            print(f"{current_time.strftime('%H:%M:%S')} - Block: {current_block}, Stake: {stake_info}")
            
            # Sleep until next interval
            time.sleep(interval_seconds)
            
        except Exception as e:
            print(f"Error monitoring stake: {e}")
            time.sleep(interval_seconds)
        
        current_time = datetime.now(timezone.utc)
    
    # Analyze and visualize results
    if stake_history:
        df = pd.DataFrame(stake_history)
        plt.figure(figsize=(10, 6))
        plt.plot(df['timestamp'], df['stake_in_tao'])
        plt.title(f"Stake Changes for {coldkey}")
        plt.xlabel("Time")
        plt.ylabel("Stake (τ)")
        plt.grid(True)
        plt.show()
        
        return df
    else:
        print("No stake history collected")
        return None

# Uncomment the following line to run actual monitoring
stake_df = monitor_stake_changes(subtensor, NETUID, HOTKEY)
# Out:
# Starting stake monitoring for hotkey 5DdAdmAW4MCdSMDJhWPDvZKCbCAAbg8WDxvSMuqvv5nPVEjc in subnet 30
# Will run for 1 minutes with 5 second intervals
# 19:04:20 - Block: 5056353, Stake: []
# 19:04:26 - Block: 5056354, Stake: []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 58
#      55         return None
#      57 # Uncomment the following line to run actual monitoring
# ---> 58 stake_df = monitor_stake_changes(subtensor, NETUID, HOTKEY)
#
# Cell In[33], line 33, in monitor_stake_changes(subtensor, netuid, coldkey, interval_seconds, duration_minutes)
#      30     print(f"{current_time.strftime('%H:%M:%S')} - Block: {current_block}, Stake: {stake_info}")
#      32     # Sleep until next interval
# ---> 33     time.sleep(interval_seconds)
#      35 except Exception as e:
#      36     print(f"Error monitoring stake: {e}")
#
# KeyboardInterrupt:

# %% [markdown]
# ## 10. Notes and Observations
#
# Document your findings here as you experiment with the Subtensor methods:
#
# 1. Most effective method for getting current stake: `get_total_stake_for_hotkey` or `get_neuron_stake_for_coldkey_and_hotkey`
# 2. Detecting epoch boundaries: Can use subnet `tempo` and `current_block` to determine epoch boundaries
# 3. Challenges and limitations: Need to poll regularly to detect stake changes as there's no event subscription mechanism
# 4. Recommended implementation approach: Periodically query stake values and compare with previous values to detect changes

# %% [markdown]
# ## 11. Summary and Implementation Plan
#
# Based on the experiments in this notebook, here's an implementation plan for the stake tracking system:
#
# ### Implementation Plan
#
# ```python
# class SubtensorStakeTracker:
#     def __init__(self, subtensor, netuid, polling_interval=60):
#         self.subtensor = subtensor
#         self.netuid = netuid
#         self.polling_interval = polling_interval
#         self.last_check_block = None
#         self.tracked_hotkeys = {}
#         self.tracked_stakes = {}
#
#     def add_tracking(self, hotkey):
#         """Add a hotkey to track"""
#         if hotkey not in self.tracked_hotkeys:
#             self.tracked_hotkeys[hotkey] = {
#                 'tracked_since': datetime.now(timezone.utc),
#                 'last_stake': self.subtensor.get_total_stake_for_hotkey(hotkey_ss58=hotkey)
#             }
#
#     def check_stakes(self):
#         """Check stake changes for tracked hotkeys"""
#         current_block = self.subtensor.get_current_block()
#         changes = []
#
#         # Check each tracked hotkey
#         for hotkey, data in self.tracked_hotkeys.items():
#             current_stake = self.subtensor.get_total_stake_for_hotkey(hotkey_ss58=hotkey)
#
#             # If stake changed, record it
#             if current_stake != data['last_stake']:
#                 change = {
#                     'hotkey': hotkey,
#                     'previous_stake': data['last_stake'],
#                     'current_stake': current_stake,
#                     'change': current_stake - data['last_stake'],
#                     'block': current_block,
#                     'timestamp': datetime.now(timezone.utc)
#                 }
#                 changes.append(change)
#
#                 # Update last stake
#                 self.tracked_hotkeys[hotkey]['last_stake'] = current_stake
#
#         self.last_check_block = current_block
#         return changes
#
#     def is_epoch_boundary(self):
#         """Check if we're at an epoch boundary"""
#         subnet_info = self.subtensor.get_subnet_info(self.netuid)
#         tempo = subnet_info.tempo
#         current_block = self.subtensor.get_current_block()
#
#         return current_block % tempo == 0
# ```
